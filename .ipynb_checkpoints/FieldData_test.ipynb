# %% [markdown]
# This is a test file for the FieldData class
# It requires input parameters from the command line as follow

# %%
#Example on how to run the code from terminal but input arguments are still not working
# Found at https://stackoverflow.com/questions/35545402/how-to-run-an-ipynb-jupyter-notebook-from-terminal (Accessed 22/02/2023)
#@echo on
#call "C:\ProgramData\Anaconda3\Scripts\activate.bat"
#ipython "path\test.ipynb"
#pause

# %%
import sys

# check if GEE is already imported to avoid requesting authenticatiation multiple times
modulename = 'ee'
if modulename not in sys.modules: 
   # import GEE and Authenticate, token or log in will be asked from web browser
   import ee
   #ee.Authenticate()
   ee.Initialize()
else:
   print('GEE already imported')
   # google earth engine already imported and authenticated


import sys
modulename = 'ipynb_FieldData'
if modulename not in sys.modules:
    # %run FieldData.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['FieldData'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_Sentinel2b'
if modulename not in sys.modules:
    # %run Sentinel2b.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_Sentinel2b'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_MapVisualisation'
if modulename not in sys.modules:
    # %run MapVisualisation.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_MapVisualisation'] = None 
#else
   # Utils modules has already been loaded somewhere else
# Out:
# GEE already imported
# Class fieldData imported
# Utils imported
# Masks class imported
# Sentinel2b class imported
# MapVisualisation class imported - uses folium library

# %%
# parsing command line inputs - Could not find a way to add the arguments in ipython
""" parser = argparse.ArgumentParser()
parser.add_argument("-in",
     required=True,
     help="The input csv file with its directory containing field plot data",
     metavar='<string>')



params       = vars(parser.parse_args())
csvFile      = params["in"   ]


print ("imported csv file     = ", csvFile ) """

# import a Sentinel 2 collection and crop Spain
countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
AOI = countries.filter(ee.Filter.eq('country_na', 'Spain'))

geometry = ee.Geometry.Polygon(
    [[[-5.586640856054208, 40.07176423657564],
      [-5.391633531835458, 40.07176423657564],
      [-5.391633531835458, 40.17257546939766],
      [-5.6106734488276455, 40.170476760191924]]])

START_DATE = '2017-01-01'
END_DATE = '2017-12-30'
masks = {}  # 'gsw': 30, 'lmask': 30, 'forestMask': {30,2021}}





s2 = Sentinel2(AOI, START_DATE, END_DATE, 50, masks)
s2.byMonth(2017)

col = s2.getCollection()


medianS2 = s2.getMedian()
bandNames = medianS2.bandNames()
print('Band names medianS2: ', bandNames.getInfo())

# Make a cloud-free Landsat 8 surface reflectance composite.
image = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
    .filterBounds(AOI) \
    .filterDate('2021-03-01', '2021-07-01')\
    .median()

# csvFile = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L2/Spain/plot234_column.csv"
csvFile = "/home/milto/Documents/fieldData/plotSample.csv"
csvDF = fieldData(csvFile, "EPSG:3042")
# csvDF.filterYearsOfInterest(2017,2018,"year")

bufferredPoints = csvDF.createBufferedPoints("CX", "CY", 10)

# csvDF.exportfeatureVectorsToDrive(col,"TestIndClassSentinel2c.csv","earth_engine_demos",10)
# csvDF.mergeFeatureVectorsToPlotData("/home/milto/Documents/FLFScripts/sampleData/mergedcsv.csv")
# csvDF.exportPlotDataWithAddedIdentifiers("/home/milto/Documents/FLFScripts/sampleData/fieldDatawithIds.csv")


s2band = s2.getCollectionToBands()
print("s2band bandnames: " , s2band.bandNames().getInfo())


## Method that Get mean and SD in every band by combining reducers.
# @param[in] img image to be interpreted - geometry is constant
def statsInternalImg(img):
    acquisitionDate = img.date().format("YYYY-MM-DD")
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    })
    return myDict


image = s2band # a contast

# Collect block, image, value triplets.
def setFeature(f) : 
    return f.set('imageId', image.id())
    
def getFeatureFrom(image) :
  return image.select('2_B2').reduceRegions({
    collection: bufferredPoints.select(['index']), 
    reducer: ee.Reducer.mean(), 
    scale: 30
  }).filter(ee.Filter.neq('mean', null)).flatten()

triplets = getFeatureFrom(image)
print(triplets)


"""
triplets = l8.map(function(image) {
  return image.select('B1').reduceRegions({
    collection: subset.select(['blockid10']), 
    reducer: ee.Reducer.mean(), 
    scale: 30
  }).filter(ee.Filter.neq('mean', null))
    .map(function(f) { 
      return f.set('imageId', image.id());
    });
}).flatten();
print(triplets.first());
"""

"""
print("s2data bandnames: " , s2band.bandNames().getInfo())
img = s2band
## Method that Get mean and SD in every band by combining reducers.
# @param[in] img image to be interpreted - geometry is constant
def statsInternalGeo(geometry):
    acquisitionDate = img.date().format("YYYY-MM-DD")
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    })
    return ee.Feature(geometry,myDict)


meanNstd = statsInternalGeo(geometry)
print("meanNstd: ", meanNstd.getInfo())


"""

img = s2.getCollectionToBands()

## Method that Get mean and SD in every band by combining reducers.
# @param[in] geometry area of interest to be interpreted - image is constant
def statsInternalGeo(geometry):
    geometry = geometry.geometry()
    acquisitionDate = img.date().format("YYYY-MM-DD")
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
        # 'maxPixels': 
    })
    return ee.Feature(geometry,myDict)


results = ee.featurecollection(bufferredPointsList.map(algorithm = statsInternalGeo))
print("results = ",results)
"""

"""
results = bufferredPoints.map(function(feature){
    stats = statsInternalGeo(feature.geometry())
    return ee.Feature(geometry,stats).copyProperties(feature)
})

resultsCollection = ee.FeatureCollection(results)



#meanNstd = statsInternalGeo(geometry)
#print("Mean and Std new labels: ", meanNstd.keys().getInfo())
#print("geometry variant s2bands: ", meanNstd.getInfo())

#meanNstdTable = bufferredPointsList.map(algorithm=statsTest)

# Export the image sample feature collection to Drive as a CSV file.
task = ee.batch.Export.table.toDrive({
  'collection': results,
  'description': 'results',
  'folder': 'earth_engine_demos',
  'fileFormat': 'CSV'
})
task.start()
"""
#meanNstdAll = col.map(algorithm=statsInternal)
meanNstdS2bands = statsInternalImg(s2band)
print("meanNstdS2bands: ", meanNstdS2bands.getInfo())
#print("Mean and Std new labels col: ", meanNstdAll.getInfo())

"""
task = ee.batch.Export.table.toDrive({
  'collection': meanNstd,
  'description': 'results',
  'folder': 'earth_engine_demos',
  'fileFormat': 'CSV'
})
task.start()
"""

# self.s2_sr_cld_col_eval_disp = self.s2_sr_cld_col_eval_disp.map(algorithm = masksHandler.updateCombinedMask)

print("   ***   EXIT   ***")
# Out:
# -1 -1 -1 -1 -1 +++++
# Band names medianS2:  []
# s2band bandnames:  ['2_B1', '2_B2', '2_B3', '2_B4', '2_B5', '2_B6', '2_B7', '2_B8', '2_B8A', '2_B9', '2_B11', '2_B12', '2_AOT', '2_WVP', '2_SCL', '2_TCI_R', '2_TCI_G', '2_TCI_B', '2_MSK_CLDPRB', '2_MSK_SNWPRB', '2_QA10', '2_QA20', '2_QA60', '2_probability', '2_clouds', '2_dark_pixels', '2_cloud_transform', '2_shadows', '2_cloudmask', '3_B1', '3_B2', '3_B3', '3_B4', '3_B5', '3_B6', '3_B7', '3_B8', '3_B8A', '3_B9', '3_B11', '3_B12', '3_AOT', '3_WVP', '3_SCL', '3_TCI_R', '3_TCI_G', '3_TCI_B', '3_MSK_CLDPRB', '3_MSK_SNWPRB', '3_QA10', '3_QA20', '3_QA60', '3_probability', '3_clouds', '3_dark_pixels', '3_cloud_transform', '3_shadows', '3_cloudmask', '4_B1', '4_B2', '4_B3', '4_B4', '4_B5', '4_B6', '4_B7', '4_B8', '4_B8A', '4_B9', '4_B11', '4_B12', '4_AOT', '4_WVP', '4_SCL', '4_TCI_R', '4_TCI_G', '4_TCI_B', '4_MSK_CLDPRB', '4_MSK_SNWPRB', '4_QA10', '4_QA20', '4_QA60', '4_probability', '4_clouds', '4_dark_pixels', '4_cloud_transform', '4_shadows', '4_cloudmask', '5_B1', '5_B2', '5_B3', '5_B4', '5_B5', '5_B6', '5_B7', '5_B8', '5_B8A', '5_B9', '5_B11', '5_B12', '5_AOT', '5_WVP', '5_SCL', '5_TCI_R', '5_TCI_G', '5_TCI_B', '5_MSK_CLDPRB', '5_MSK_SNWPRB', '5_QA10', '5_QA20', '5_QA60', '5_probability', '5_clouds', '5_dark_pixels', '5_cloud_transform', '5_shadows', '5_cloudmask', '6_B1', '6_B2', '6_B3', '6_B4', '6_B5', '6_B6', '6_B7', '6_B8', '6_B8A', '6_B9', '6_B11', '6_B12', '6_AOT', '6_WVP', '6_SCL', '6_TCI_R', '6_TCI_G', '6_TCI_B', '6_MSK_CLDPRB', '6_MSK_SNWPRB', '6_QA10', '6_QA20', '6_QA60', '6_probability', '6_clouds', '6_dark_pixels', '6_cloud_transform', '6_shadows', '6_cloudmask', '7_B1', '7_B2', '7_B3', '7_B4', '7_B5', '7_B6', '7_B7', '7_B8', '7_B8A', '7_B9', '7_B11', '7_B12', '7_AOT', '7_WVP', '7_SCL', '7_TCI_R', '7_TCI_G', '7_TCI_B', '7_MSK_CLDPRB', '7_MSK_SNWPRB', '7_QA10', '7_QA20', '7_QA60', '7_probability', '7_clouds', '7_dark_pixels', '7_cloud_transform', '7_shadows', '7_cloudmask', '8_B1', '8_B2', '8_B3', '8_B4', '8_B5', '8_B6', '8_B7', '8_B8', '8_B8A', '8_B9', '8_B11', '8_B12', '8_AOT', '8_WVP', '8_SCL', '8_TCI_R', '8_TCI_G', '8_TCI_B', '8_MSK_CLDPRB', '8_MSK_SNWPRB', '8_QA10', '8_QA20', '8_QA60', '8_probability', '8_clouds', '8_dark_pixels', '8_cloud_transform', '8_shadows', '8_cloudmask', '9_B1', '9_B2', '9_B3', '9_B4', '9_B5', '9_B6', '9_B7', '9_B8', '9_B8A', '9_B9', '9_B11', '9_B12', '9_AOT', '9_WVP', '9_SCL', '9_TCI_R', '9_TCI_G', '9_TCI_B', '9_MSK_CLDPRB', '9_MSK_SNWPRB', '9_QA10', '9_QA20', '9_QA60', '9_probability', '9_clouds', '9_dark_pixels', '9_cloud_transform', '9_shadows', '9_cloudmask', '10_B1', '10_B2', '10_B3', '10_B4', '10_B5', '10_B6', '10_B7', '10_B8', '10_B8A', '10_B9', '10_B11', '10_B12', '10_AOT', '10_WVP', '10_SCL', '10_TCI_R', '10_TCI_G', '10_TCI_B', '10_MSK_CLDPRB', '10_MSK_SNWPRB', '10_QA10', '10_QA20', '10_QA60', '10_probability', '10_clouds', '10_dark_pixels', '10_cloud_transform', '10_shadows', '10_cloudmask', '11_B1', '11_B2', '11_B3', '11_B4', '11_B5', '11_B6', '11_B7', '11_B8', '11_B8A', '11_B9', '11_B11', '11_B12', '11_AOT', '11_WVP', '11_SCL', '11_TCI_R', '11_TCI_G', '11_TCI_B', '11_MSK_CLDPRB', '11_MSK_SNWPRB', '11_QA10', '11_QA20', '11_QA60', '11_probability', '11_clouds', '11_dark_pixels', '11_cloud_transform', '11_shadows', '11_cloudmask']
# s2data bandnames:  ['2_B1', '2_B2', '2_B3', '2_B4', '2_B5', '2_B6', '2_B7', '2_B8', '2_B8A', '2_B9', '2_B11', '2_B12', '2_AOT', '2_WVP', '2_SCL', '2_TCI_R', '2_TCI_G', '2_TCI_B', '2_MSK_CLDPRB', '2_MSK_SNWPRB', '2_QA10', '2_QA20', '2_QA60', '2_probability', '2_clouds', '2_dark_pixels', '2_cloud_transform', '2_shadows', '2_cloudmask', '3_B1', '3_B2', '3_B3', '3_B4', '3_B5', '3_B6', '3_B7', '3_B8', '3_B8A', '3_B9', '3_B11', '3_B12', '3_AOT', '3_WVP', '3_SCL', '3_TCI_R', '3_TCI_G', '3_TCI_B', '3_MSK_CLDPRB', '3_MSK_SNWPRB', '3_QA10', '3_QA20', '3_QA60', '3_probability', '3_clouds', '3_dark_pixels', '3_cloud_transform', '3_shadows', '3_cloudmask', '4_B1', '4_B2', '4_B3', '4_B4', '4_B5', '4_B6', '4_B7', '4_B8', '4_B8A', '4_B9', '4_B11', '4_B12', '4_AOT', '4_WVP', '4_SCL', '4_TCI_R', '4_TCI_G', '4_TCI_B', '4_MSK_CLDPRB', '4_MSK_SNWPRB', '4_QA10', '4_QA20', '4_QA60', '4_probability', '4_clouds', '4_dark_pixels', '4_cloud_transform', '4_shadows', '4_cloudmask', '5_B1', '5_B2', '5_B3', '5_B4', '5_B5', '5_B6', '5_B7', '5_B8', '5_B8A', '5_B9', '5_B11', '5_B12', '5_AOT', '5_WVP', '5_SCL', '5_TCI_R', '5_TCI_G', '5_TCI_B', '5_MSK_CLDPRB', '5_MSK_SNWPRB', '5_QA10', '5_QA20', '5_QA60', '5_probability', '5_clouds', '5_dark_pixels', '5_cloud_transform', '5_shadows', '5_cloudmask', '6_B1', '6_B2', '6_B3', '6_B4', '6_B5', '6_B6', '6_B7', '6_B8', '6_B8A', '6_B9', '6_B11', '6_B12', '6_AOT', '6_WVP', '6_SCL', '6_TCI_R', '6_TCI_G', '6_TCI_B', '6_MSK_CLDPRB', '6_MSK_SNWPRB', '6_QA10', '6_QA20', '6_QA60', '6_probability', '6_clouds', '6_dark_pixels', '6_cloud_transform', '6_shadows', '6_cloudmask', '7_B1', '7_B2', '7_B3', '7_B4', '7_B5', '7_B6', '7_B7', '7_B8', '7_B8A', '7_B9', '7_B11', '7_B12', '7_AOT', '7_WVP', '7_SCL', '7_TCI_R', '7_TCI_G', '7_TCI_B', '7_MSK_CLDPRB', '7_MSK_SNWPRB', '7_QA10', '7_QA20', '7_QA60', '7_probability', '7_clouds', '7_dark_pixels', '7_cloud_transform', '7_shadows', '7_cloudmask', '8_B1', '8_B2', '8_B3', '8_B4', '8_B5', '8_B6', '8_B7', '8_B8', '8_B8A', '8_B9', '8_B11', '8_B12', '8_AOT', '8_WVP', '8_SCL', '8_TCI_R', '8_TCI_G', '8_TCI_B', '8_MSK_CLDPRB', '8_MSK_SNWPRB', '8_QA10', '8_QA20', '8_QA60', '8_probability', '8_clouds', '8_dark_pixels', '8_cloud_transform', '8_shadows', '8_cloudmask', '9_B1', '9_B2', '9_B3', '9_B4', '9_B5', '9_B6', '9_B7', '9_B8', '9_B8A', '9_B9', '9_B11', '9_B12', '9_AOT', '9_WVP', '9_SCL', '9_TCI_R', '9_TCI_G', '9_TCI_B', '9_MSK_CLDPRB', '9_MSK_SNWPRB', '9_QA10', '9_QA20', '9_QA60', '9_probability', '9_clouds', '9_dark_pixels', '9_cloud_transform', '9_shadows', '9_cloudmask', '10_B1', '10_B2', '10_B3', '10_B4', '10_B5', '10_B6', '10_B7', '10_B8', '10_B8A', '10_B9', '10_B11', '10_B12', '10_AOT', '10_WVP', '10_SCL', '10_TCI_R', '10_TCI_G', '10_TCI_B', '10_MSK_CLDPRB', '10_MSK_SNWPRB', '10_QA10', '10_QA20', '10_QA60', '10_probability', '10_clouds', '10_dark_pixels', '10_cloud_transform', '10_shadows', '10_cloudmask', '11_B1', '11_B2', '11_B3', '11_B4', '11_B5', '11_B6', '11_B7', '11_B8', '11_B8A', '11_B9', '11_B11', '11_B12', '11_AOT', '11_WVP', '11_SCL', '11_TCI_R', '11_TCI_G', '11_TCI_B', '11_MSK_CLDPRB', '11_MSK_SNWPRB', '11_QA10', '11_QA20', '11_QA60', '11_probability', '11_clouds', '11_dark_pixels', '11_cloud_transform', '11_shadows', '11_cloudmask']
# meanNstdS2bands:  {'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[-5.586640856054208, 40.07176423657564], [-5.391633531835458, 40.07176423657564], [-5.391633531835458, 40.17257546939766], [-5.6106734488276455, 40.170476760191924], [-5.586640856054208, 40.07176423657564]]]}, 'properties': {'10_AOT_mean': 109.5461598451833, '10_AOT_stdDev': 5.607193254438347, '10_B11_mean': 1872.470938095848, '10_B11_stdDev': 512.5067186491282, '10_B12_mean': 1173.317959662552, '10_B12_stdDev': 465.2
': 0.077975503498991, '10_cloudmask_mean': 0, '10_cloudmask_stdDev': 0, '10_clouds_mean': 0, '10_clouds_stdDev': 0, '10_dark_pixels_mean': 0.11139052377466299, '10_dark_pixels_stdDev': 0.24053181444025018, '10_probability_mean': 4.259929604552955, '10_probability_stdDev': 2.0995181604039184, '10_shadows_mean': 0, '10_shadows_stdDev': 0, '11_AOT_mean': 110.0430155335975, '11_AOT_stdDev': 5.5599366771906, '11_B11_mean': 1932.1404062421134, '11_B11_stdDev': 417.72401850064665, '11_B12_mean': 1228.2635738028548, '11_B12_stdDev': 347.2361341155943, '11_B1_mean': 248.44013457304274, '11_B1_stdDev': 76.84476197561209, '11_B2_mean': 336.2155860565725, '11_B2_stdDev': 100.86712387711995, '11_B3_mean': 486.0984036943126, '11_B3_stdDev': 136.75144621743615, '11_B4_mean': 589.2961599600721, '11_B4_stdDev': 187.47764504481637, '11_B5_mean': 936.5247469775843, '11_B5_stdDev': 218.75033701909393, '11_B6_mean': 1485.4661833700734, '11_B6_stdDev': 291.36288437315625, '11_B7_mean': 1690.669303393896, '11_B7_stdDev': 318.3113712953356, '11_B8A_mean': 1950.1641640161502, '11_B8A_stdDev': 338.6753830591061, '11_B8_mean': 1874.8059854742155, '11_B8_stdDev': 336.15227932555126, '11_B9_mean': 1981.141397858354, '11_B9_stdDev': 302.70991080954053, '11_MSK_CLDPRB_mean': None, '11_MSK_CLDPRB_stdDev': None, '11_MSK_SNWPRB_mean': None, '11_MSK_SNWPRB_stdDev': None, '11_QA10_mean': 0, '11_QA10_stdDev': 0, '11_QA20_mean': 0, '11_QA20_stdDev': 0, '11_QA60_mean': 103.61256860660846, '11_QA60_stdDev': 305.81076086115013, '11_SCL_mean': 4.338720873642514, '11_SCL_stdDev': 0.850450151545817, '11_TCI_B_mean': 34.338925263086765, '11_TCI_B_stdDev': 10.14997693304539, '11_TCI_G_mean': 49.774926550774666, '11_TCI_G_stdDev': 13.541105330504564, '11_TCI_R_mean': 60.537718641558, '11_TCI_R_stdDev': 18.389841022708552, '11_WVP_mean': 797.2996583628706, '11_WVP_stdDev': 109.44106937954182, '11_cloud_transform_mean': 0.00026367272321188497, '11_cloud_transform_stdDev': 0.007969704789416275, '11_cloudmask_mean': 0, '11_cloudmask_stdDev': 0, '11_clouds_mean': 0, '11_clouds_stdDev': 0, '11_dark_pixels_mean': 0.09101982405274266, '11_dark_pixels_stdDev': 0.24884912940695458, '11_probability_mean': 9.819713689336302, '11_probability_stdDev': 3.606042385638449, '11_shadows_mean': 0, '11_shadows_stdDev': 0, '2_AOT_mean': None, '2_AOT_stdDev': None, '2_B11_mean': None, '2_B11_std ...
#    ***   EXIT   ***

# %%
#%run MapVisualisation.ipynb
my_map = folium.Map(location=[40,-3], zoom_start=5, height=400)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)
# Add Land Mask to the map
#my_map.add_ee_layer(s2_col, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 2500, 'gamma': 1.1}, 'median'      )
my_map.add_ee_layer(bufferredPoints, {},'bufferredPoints')
my_map.add_ee_layer(geometry,{},"geometry")
my_map.add_ee_layer(medianS2,{'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 2500, 'gamma': 1.1}, 'median'      )

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())
plugins.Fullscreen().add_to(my_map)

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
