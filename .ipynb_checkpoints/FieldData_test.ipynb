# %% [markdown]
# This is a test file for the FieldData class
# It requires input parameters from the command line as follow

# %%
#Example on how to run the code from terminal but input arguments are still not working
# Found at https://stackoverflow.com/questions/35545402/how-to-run-an-ipynb-jupyter-notebook-from-terminal (Accessed 22/02/2023)
#@echo on
#call "C:\ProgramData\Anaconda3\Scripts\activate.bat"
#ipython "path\test.ipynb"
#pause

# %%
import sys

# check if GEE is already imported to avoid requesting authenticatiation multiple times
modulename = 'ee'
if modulename not in sys.modules: 
   # import GEE and Authenticate, token or log in will be asked from web browser
   import ee
   #ee.Authenticate()
   ee.Initialize()
else:
   print('GEE already imported')
   # google earth engine already imported and authenticated


import sys
modulename = 'ipynb_FieldData'
if modulename not in sys.modules:
    # %run FieldData.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['FieldData'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_Sentinel2b'
if modulename not in sys.modules:
    # %run Sentinel2b.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_Sentinel2b'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_MapVisualisation'
if modulename not in sys.modules:
    # %run MapVisualisation.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_MapVisualisation'] = None 
#else
   # Utils modules has already been loaded somewhere else
# Out:
# GEE already imported
# GEE already imported
# Class fieldData imported

# %%
# parsing command line inputs - Could not find a way to add the arguments in ipython
""" parser = argparse.ArgumentParser()
parser.add_argument("-in",
     required=True,
     help="The input csv file with its directory containing field plot data",
     metavar='<string>')



params       = vars(parser.parse_args())
csvFile      = params["in"   ]


print ("imported csv file     = ", csvFile ) """

# import a Sentinel 2 collection and crop Spain
countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
AOI = countries.filter(ee.Filter.eq('country_na', 'Spain'))

geometry = ee.Geometry.Polygon(
    [[[-5.586640856054208, 40.07176423657564],
      [-5.391633531835458, 40.07176423657564],
      [-5.391633531835458, 40.17257546939766],
      [-5.6106734488276455, 40.170476760191924]]])

START_DATE = '2017-01-01'
END_DATE = '2017-12-30'
masks = {}  # 'gsw': 30, 'lmask': 30, 'forestMask': {30,2021}}





s2 = Sentinel2(AOI, START_DATE, END_DATE, 50, masks)
s2.byMonth(2017)

col = s2.getCollection()


medianS2 = s2.getMedian()
bandNames = medianS2.bandNames()
print('Band names medianS2: ', bandNames.getInfo())

# Make a cloud-free Landsat 8 surface reflectance composite.
image = ee.ImageCollection('LANDSAT/LC08/C02/T1_L2') \
    .filterBounds(AOI) \
    .filterDate('2021-03-01', '2021-07-01')\
    .median()

# csvFile = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L2/Spain/plot234_column.csv"
csvFile = "/home/milto/Documents/fieldData/plotSample.csv"
csvDF = fieldData(csvFile, "EPSG:3042")
# csvDF.filterYearsOfInterest(2017,2018,"year")

bufferredPoints = csvDF.createBufferedPoints("CX", "CY", 10)

# csvDF.exportfeatureVectorsToDrive(col,"TestIndClassSentinel2c.csv","earth_engine_demos",10)
# csvDF.mergeFeatureVectorsToPlotData("/home/milto/Documents/FLFScripts/sampleData/mergedcsv.csv")
# csvDF.exportPlotDataWithAddedIdentifiers("/home/milto/Documents/FLFScripts/sampleData/fieldDatawithIds.csv")


s2band = s2.getCollectionToBands()
print("s2band bandnames: " , s2band.bandNames().getInfo())
# Collect block, image, value triplets.


## Method that Get mean and SD in every band by combining reducers.
# @param[in] img image to be interpreted - geometry is constant
def statsInternalImg(img):
    acquisitionDate = img.date().format("YYYY-MM-DD")
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    }).set('geometry',geometry)
    return myDict

meanNstdS2bands = statsInternalImg(s2band)
print("meanNstdS2bands: ", meanNstdS2bands.getInfo())

"""
image = s2band # a contast


    
def getFeatureFrom(image) :
  return image.select('2_B2').reduceRegions({
    'collection': bufferredPoints, 
    'reducer': ee.Reducer.mean(), 
    'scale': 30
  }).filter(ee.Filter.neq('mean', null)).flatten()

triplets = getFeatureFrom(image)
print("triplets",triplets)



triplets = l8.map(function(image) {
  return image.select('B1').reduceRegions({
    collection: subset.select(['blockid10']), 
    reducer: ee.Reducer.mean(), 
    scale: 30
  }).filter(ee.Filter.neq('mean', null))
    .map(function(f) { 
      return f.set('imageId', image.id());
    });
}).flatten();
print(triplets.first());
"""


"""
"""

print("s2data bandnames: " , s2band.bandNames().getInfo())
img = s2band
## Method that Get mean and SD in every band by combining reducers.
# @param[in] img image to be interpreted - geometry is constant
def statsInternalGeo(geometry):
    myDict = img.select('2_B4').reduceRegion(**{
        'reducer': ee.Reducer.mean(),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    })
    return myDict


meanNstd = statsInternalGeo(geometry)
print("meanNstd: ", meanNstd.getInfo())



#results = ee.featurecollection(bufferredPointsList.map(algorithm = statsInternalGeo))
#print("results = ",results)


"""
results = bufferredPoints.map(function(feature){
    stats = statsInternalGeo(feature.geometry())
    return ee.Feature(geometry,stats).copyProperties(feature)
})

resultsCollection = ee.FeatureCollection(results)



#meanNstd = statsInternalGeo(geometry)
#print("Mean and Std new labels: ", meanNstd.keys().getInfo())
#print("geometry variant s2bands: ", meanNstd.getInfo())

#meanNstdTable = bufferredPointsList.map(algorithm=statsTest)

# Export the image sample feature collection to Drive as a CSV file.
task = ee.batch.Export.table.toDrive({
  'collection': results,
  'description': 'results',
  'folder': 'earth_engine_demos',
  'fileFormat': 'CSV'
})
task.start()
"""
#meanNstdAll = col.map(algorithm=statsInternal)

#print("Mean and Std new labels col: ", meanNstdAll.getInfo())

"""
task = ee.batch.Export.table.toDrive({
  'collection': meanNstd,
  'description': 'results',
  'folder': 'earth_engine_demos',
  'fileFormat': 'CSV'
})
task.start()
"""

# self.s2_sr_cld_col_eval_disp = self.s2_sr_cld_col_eval_disp.map(algorithm = masksHandler.updateCombinedMask)

print("   ***   EXIT   ***")
# Out:
# -1 -1 -1 -1 -1 +++++
# Band names medianS2:  []
# s2band bandnames:  ['2_B1', '2_B2', '2_B3', '2_B4', '2_B5', '2_B6', '2_B7', '2_B8', '2_B8A', '2_B9', '2_B11', '2_B12', '3_B1', '3_B2', '3_B3', '3_B4', '3_B5', '3_B6', '3_B7', '3_B8', '3_B8A', '3_B9', '3_B11', '3_B12', '4_B1', '4_B2', '4_B3', '4_B4', '4_B5', '4_B6', '4_B7', '4_B8', '4_B8A', '4_B9', '4_B11', '4_B12', '5_B1', '5_B2', '5_B3', '5_B4', '5_B5', '5_B6', '5_B7', '5_B8', '5_B8A', '5_B9', '5_B11', '5_B12', '6_B1', '6_B2', '6_B3', '6_B4', '6_B5', '6_B6', '6_B7', '6_B8', '6_B8A', '6_B9', '6_B11', '6_B12', '7_B1', '7_B2', '7_B3', '7_B4', '7_B5', '7_B6', '7_B7', '7_B8', '7_B8A', '7_B9', '7_B11', '7_B12', '8_B1', '8_B2', '8_B3', '8_B4', '8_B5', '8_B6', '8_B7', '8_B8', '8_B8A', '8_B9', '8_B11', '8_B12', '9_B1', '9_B2', '9_B3', '9_B4', '9_B5', '9_B6', '9_B7', '9_B8', '9_B8A', '9_B9', '9_B11', '9_B12', '10_B1', '10_B2', '10_B3', '10_B4', '10_B5', '10_B6', '10_B7', '10_B8', '10_B8A', '10_B9', '10_B11', '10_B12', '11_B1', '11_B2', '11_B3', '11_B4', '11_B5', '11_B6', '11_B7', '11_B8', '11_B8A', '11_B9', '11_B11', '11_B12']
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[7], line 79
#      71     myDict = img.reduceRegion({
#      72         'reducer': ee.Reducer.mean(),
#      73         'geometry': geometry,
#      74         'scale': 300,
#      75         'bestEffort': True  # Use maxPixels if you care about scale.
#      76     }).filter(ee.Filter.neq('mean', None)).set('geometry',geometry)
#      77     return myDict
# ---> 79 meanNstdS2bands = statsInternalImg(s2band)
#      80 print("meanNstdS2bands: ", meanNstdS2bands.getInfo())
#      82 """
#      83 image = s2band # a contast
#      84
#    (...)
#     109 print(triplets.first());
#     110 """
#
# Cell In[7], line 71, in statsInternalImg(img)
#      69 def statsInternalImg(img):
#      70     acquisitionDate = img.date().format("YYYY-MM-DD")
# ---> 71     myDict = img.reduceRegion({
#      72         'reducer': ee.Reducer.mean(),
#      73         'geometry': geometry,
#      74         'scale': 300,
#      75         'bestEffort': True  # Use maxPixels if you care about scale.
#      76     }).filter(ee.Filter.neq('mean', None)).set('geometry',geometry)
#      77     return myDict
#
# File ~/.local/lib/python3.10/site-packages/ee/apifunction.py:205, in ApiFunction.importApi.<locals>.MakeBoundFunction.<locals>.<lambda>(*args, **kwargs)
#     203 def MakeBoundFunction(func):
#     204   # We need the lambda to capture "func" from the enclosing scope.
# --> 205   return lambda *args, **kwargs: func.call(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ee/function.py:67, in Function.call(self, *args, **kwargs)
#      55 def call(self, *args, **kwargs):
#      56   """Calls the function with the given positional and keyword arguments.
#      57
#      58   Args:
#    (...)
#      65     to that type.
#      66   """
# ---> 67   return self.apply(self.nameArgs(args, kwargs))
#
# File ~/.local/lib/python3.10/site-packages/ee/function.py:80, in Function.apply(self, named_args)
#      69 def apply(self, named_args):
#      70   """Calls the function with a dictionary of named arguments.
#      71
#      72   Args:
#    (...)
#      78     to that type.
#      79   """
# ---> 80   result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      81   return Function._promoter(result, self.getReturnType())
#
# File ~/.local/lib/python3.10/site-packages/ee/function.py:107, in Function.promoteArgs(self, args)
#     105 name = spec['name']
#     106 if name in args:
# --> 107   promoted_args[name] = Function._promoter(args[name], spec['type'])
#     108 elif not spec.get('optional'):
#     109   raise ee_exception.EEException(
#     110       'Required argument (%s) missing to function: %s'
#     111       % (name, self.name))
#
# File ~/.local/lib/python3.10/site-packages/ee/__init__.py:298, in _Promote(arg, klass)
#     295       raise EEException('Unknown algorithm: {0}.{1}'.format(klass, arg))
#     296   else:
#     297     # Client-side cast.
# --> 298     return cls(arg)
#     299 else:
#     300   return arg
#
# File ~/.local/lib/python3.10/site-packages/ee/computedobject.py:31, in ComputedObjectMetaclass.__call__(cls, *args, **kwargs)
#      29   return args[0]
#      30 else:
# ---> 31   return type.__call__(cls, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ee/__init__.py:412, in _MakeClass.<locals>.init(self, *args)
#     408   raise EEException(
#     409       'Too many arguments for ee.{0}(): {1}'.format(name, args))
#     410 elif firstArgIsPrimitive:
#     411   # Can't cast a primitive.
# --> 412   raise EEException(
#     413       'Invalid argument for ee.{0}(): {1}.  '
#     414       'Must be a ComputedObject.'.format(name, args))
#     415 else:
#     416   result = args[0]
#
# EEException: Invalid argument for ee.Reducer(): ({'reducer': <ee.Reducer object at 0x7f19b4bcec50>, 'geometry': ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "GeometryConstructors.Polygon",
#     "arguments": {
#       "coordinates": {
#         "constantValue": [
#           [
#             [
#               -5.586640856054208,
#               40.07176423657564
#             ],
#             [
#               -5.391633531835458,
#               40.07176423657564
#             ],
#             [
#               -5.391633531835458,
#               40.17257546939766
#             ],
#             [
#               -5.6106734488276455,
#               40.170476760191924
#             ]
#           ]
#         ]
#       },
#       "evenOdd": {
#         "constantValue": true
#       }
#     }
#   }
# }), 'scale': 300, 'bestEffort': True},).  Must be a ComputedObject.

# %%
#%run MapVisualisation.ipynb
my_map = folium.Map(location=[40,-3], zoom_start=5, height=400)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)
# Add Land Mask to the map
#my_map.add_ee_layer(s2_col, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 2500, 'gamma': 1.1}, 'median'      )
my_map.add_ee_layer(bufferredPoints, {},'bufferredPoints')
my_map.add_ee_layer(geometry,{},"geometry")
my_map.add_ee_layer(medianS2,{'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 2500, 'gamma': 1.1}, 'median'      )

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())
plugins.Fullscreen().add_to(my_map)

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
