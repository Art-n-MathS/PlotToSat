# %% [markdown]
# This following code contain test cases for the MapVisualisation Module.
#
# Version : 1.0
# Date    : Feb 2023
# Author  : Dr Milto Miltiaodu

# %%
# %run MapVisualisation.ipynb


# Set visualization parameters.
vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

# Create a folium map object.
my_map = folium.Map(location=[40,-3], zoom_start=5, height=400)


# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)

# Add the elevation model to the map object.
dem = ee.Image('USGS/SRTMGL1_003')
my_map.add_ee_layer(dem.updateMask(dem.gt(0)), vis_params, 'DEM')

# Display ee.Image
dataset = ee.Image('JRC/GSW1_1/GlobalSurfaceWater')
occurrence = dataset.select('occurrence');
occurrenceVis = {'min': 0.0, 'max': 100.0, 'palette': ['ffffff', 'ffbbbb', '0000ff']}
my_map.add_ee_layer(occurrence, occurrenceVis, 'JRC Surface Water')

# Display ee.FeatureCollection
countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
geometry = countries.filter(ee.Filter.eq('country_na', 'Spain'))
my_map.add_ee_layer(geometry, {}, 'Spain')


# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())
plugins.Fullscreen().add_to(my_map)

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# MapVisualisation class imported - uses folium library
# C:\Users\mm1397\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\ee\deprecation.py:207: DeprecationWarning:
#
# Attention required for JRC/GSW1_1/GlobalSurfaceWater! You are using a deprecated asset.
# To ensure continued functionality, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/JRC_GSW1_1_GlobalSurfaceWater
#
#   warnings.warn(warning, category=DeprecationWarning)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc89263ba7dc4975ce0c298a32d9111c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 400.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc89263ba7dc4975ce0c298a32d9111c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc89263ba7dc4975ce0c298a32d9111c = L.map(
#                 &quot;map_cc89263ba7dc4975ce0c298a32d9111c&quot;,
#                 {
#                     center: [40.0, -3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9819a749e37031ad701b98719fcaff6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a9819a749e37031ad701b98719fcaff6.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var tile_layer_3c1bc18a094eae72b77900a73abed8a9 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c1bc18a094eae72b77900a73abed8a9.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var tile_layer_c76b824605b94afc0a399f708556b685 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c76b824605b94afc0a399f708556b685.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var tile_layer_abbde32c92130a3ac00cf6f739a11af2 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/999a86862b85a7c89a94ff39e5419394-41e01ae9532c5b73d97cd60674133cee/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_abbde32c92130a3ac00cf6f739a11af2.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var tile_layer_b6245bbfc5b68af3021ac961bb92ab6f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/bd6d1e969748cd63955226b24412bca1-bbc3aa2c3c1d1d4472f3308cf597f0c7/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b6245bbfc5b68af3021ac961bb92ab6f.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var tile_layer_c762c55b9c7f4f5dd655030de57c0151 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/735cd043aafbfe9fcbb4ee73470d7b71-c982fae60879b4571d11b7fd0f61995f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c762c55b9c7f4f5dd655030de57c0151.addTo(map_cc89263ba7dc4975ce0c298a32d9111c);
#
#
#             var layer_control_559eb133f3df4310616d9ba72eded460_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a9819a749e37031ad701b98719fcaff6,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_3c1bc18a094eae72b77900a73abed8a9,
#                     &quot;Google Satellite&quot; : tile_layer_c76b824605b94afc0a399f708556b685,
#                     &quot;DEM&quot; : tile_layer_abbde32c92130a3ac00cf6f739a11af2,
#                     &quot;JRC Surface Water&quot; : tile_layer_b6245bbfc5b68af3021ac961bb92ab6f,
#                     &quot;Spain&quot; : tile_layer_c762c55b9c7f4f5dd655030de57c0151,
