# %%
import ee

# %%
import sys
ee.Initialize()
# check if GEE is already imported to avoid requesting authenticatiation multiple times
modulename = 'ee'
if modulename not in sys.modules: 
   # import GEE and Authenticate, token or log in will be asked from web browser
   import ee
   ee.Authenticate()
   ee.Initialize()
else:
   print('GEE already imported')
   # google earth engine already imported and authenticated

import sys
modulename = 'ipynb_FieldData'
if modulename not in sys.modules:
    # %run FieldData.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['FieldData'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_Sentinel2b'
if modulename not in sys.modules:
    # %run Sentinel2b.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_Sentinel2b'] = None 
#else
   # Utils modules has already been loaded somewhere else

modulename = 'ipynb_MapVisualisation'
if modulename not in sys.modules:
    # %run MapVisualisation.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_MapVisualisation'] = None 
#else
   # Utils modules has already been loaded somewhere else

sys.setrecursionlimit(9000)
# Out:
# GEE already imported
# GEE already imported
# Class fieldData imported

# %%
countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
AOI = countries.filter(ee.Filter.eq('country_na', 'Spain'))

geometry = ee.Geometry.Polygon(
        [[[-5.586640856054208, 40.07176423657564],
          [-5.391633531835458, 40.07176423657564],
          [-5.391633531835458, 40.17257546939766],
          [-5.6106734488276455, 40.170476760191924]]])

point = ee.Geometry.Point([-5.535568667322441, 40.13010447293477]);

bpoint = point.buffer(100)

fSTART_DATE = '2000-01-01'
fEND_DATE = '2020-12-31'
masks = {'gsw': 30, 'lmask': 30, 'forestMask': {'buffer':30, 'startDate':fSTART_DATE, 'endDate':fEND_DATE},'aspectDes':0}

START_DATE = '2021-03-01'
END_DATE = '2021-07-01'

s2 = Sentinel2(AOI,START_DATE,END_DATE,50, masks)
s2.byMonth(2021)



img = s2.getCollectionToBands()
#img = img.select('2_B2')
bandNamesImg = img.bandNames().getInfo()
print('Band names img: ', bandNamesImg)

def statsInternalImg(img):
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': bpoint,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    }).set('geometry',geometry)
    return myDict

#imgStats = statsInternalImg(img)
#print('imgStats: ', imgStats.getInfo())



def statsInternalGeo(geometry):
    myDict = img.reduceRegion(**{
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'geometry': geometry,
        'scale': 300,
        'bestEffort': True  # Use maxPixels if you care about scale.
    }).set('geometry',geometry)
    return myDict





s2 = Sentinel2(AOI,START_DATE,END_DATE,50, masks)
s2.byMonth(2021)
col = s2.getCollection()
medianS2 = s2.getMedian()
bandNames = medianS2.bandNames()
print('Band names medianS2: ', bandNames.getInfo())



#csvFile = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L2/Spain/plot234_column.csv"
csvFile = "/home/milto/Documents/fieldData/plotSample.csv"
#csvFile = "/home/milto/Documents/fieldData/plot234_column.csv"
csvDF = fieldData(csvFile,"EPSG:3042")
#csvDF.filterYearsOfInterest(2017,2018,"year")

bufferredPoints = csvDF.createBufferedPoints("CX","CY",10)

sampleImg = img.select(['2_B2'])




s2bands = s2.getCollectionToBands()
#img = img.select('2_B2')
bandNamesImg = s2bands.bandNames().getInfo()
print('Band names s2bands: ', bandNamesImg)

for band in bandNamesImg :
    if(not isinstance(band,str)):
        bandNamesImg.remove(band)

bandNamesCollection = ee.FeatureCollection(
    [ee.Feature(None, {'band': band}) for band in bandNamesImg]
)

#def addBandName(name):

# get mean and std for one band of an image for each buffered point
def getInfoRegions(bandName):
   # bnamestr = bandName.get('band')
    return s2bands.select([bandName]).reduceRegions(**{
        'collection': bufferredPoints.select("indexField"),
        'reducer': ee.Reducer.mean().combine(**{
            'reducer2': ee.Reducer.stdDev(),
            'sharedInputs': True
        }),
        'scale': 50#,
        #'bestEffort': True  # Use maxPixels if you care about scale.
    }).map(lambda feature: feature.set('bandName',bandName))  \
      .filter(ee.Filter.neq('mean',None))

#def removeNone(entry):
#    return entry.set('indexField','mean','')

featureCollection = ee.FeatureCollection([])
for band in bandNamesImg:
    features = getInfoRegions(band)
    featureCollection = featureCollection.merge(features)




def processMatchesMean(row):
    # Get the list of all features with a unique row ID.
    matches = ee.List(row.get('matches'))
    # Map a function over the list of rows to return a list of column ID and value.
    values = matches.map(lambda feature: [ee.Feature(feature).get('bandName'), ee.Feature(feature).get('mean')])
    # Return the row with its ID property and properties for all matching column IDs storing the output of the reducer.
    return row.select(['indexField']).set(ee.Dictionary(values.flatten()))


## Format a table of triplets into a 2D table of rowId x colId.
def formatMean (table):
    # Get a FeatureCollection with unique row IDs.
    rows = table.distinct('indexField')
    filterEq = ee.Filter.equals(leftField='indexField', rightField='indexField')
    innerJoin = ee.Join.saveAll('matches')
    toyJoin = innerJoin.apply(primary=rows, secondary=table, condition=filterEq)
    return toyJoin.map(algorithm = processMatchesMean)

def processMatchesStd(row):
    # Get the list of all features with a unique row ID.
    matches = ee.List(row.get('matches'))
    # Map a function over the list of rows to return a list of column ID and value.
    values = matches.map(lambda feature: [ee.Feature(feature).get('bandName'), ee.Feature(feature).get('stdDev')])
    # Return the row with its ID property and properties for all matching column IDs storing the output of the reducer.
    return row.select(['indexField']).set(ee.Dictionary(values.flatten()))


## Format a table of triplets into a 2D table of rowId x colId.
def formatStd (table):
    # Get a FeatureCollection with unique row IDs.
    rows = table.distinct('indexField')
    filterEq = ee.Filter.equals(leftField='indexField', rightField='indexField')
    innerJoin = ee.Join.saveAll('matches')
    toyJoin = innerJoin.apply(primary=rows, secondary=table, condition=filterEq)
    return toyJoin.map(algorithm = processMatchesStd)




tableMean = formatMean(featureCollection)
tableStd  = formatStd (featureCollection)


task = ee.batch.Export.table.toDrive(**{
   'collection':tableMean,
   'description':'tableMeanCsvFile',
   'folder': 'earth_engine_demos',
   'fileFormat':'CSV'
})
task.start()

task = ee.batch.Export.table.toDrive(**{
   'collection':tableStd,
   'description':'tableStdCsvFile',
   'folder': 'earth_engine_demos',
   'fileFormat':'CSV'
})
task.start()
# Out:
# 30 30 0 -1 30 +++++
# Band names img:  ['2_B1', '2_B2', '2_B3', '2_B4', '2_B5', '2_B6', '2_B7', '2_B8', '2_B8A', '2_B9', '2_B11', '2_B12', '3_B1', '3_B2', '3_B3', '3_B4', '3_B5', '3_B6', '3_B7', '3_B8', '3_B8A', '3_B9', '3_B11', '3_B12', '4_B1', '4_B2', '4_B3', '4_B4', '4_B5', '4_B6', '4_B7', '4_B8', '4_B8A', '4_B9', '4_B11', '4_B12', '5_B1', '5_B2', '5_B3', '5_B4', '5_B5', '5_B6', '5_B7', '5_B8', '5_B8A', '5_B9', '5_B11', '5_B12']
# 30 30 0 -1 30 +++++
# Band names medianS2:  []
# /tmp/ipykernel_2064402/541937665.py:18: DtypeWarning: Columns (27,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(csvFileName)
# Band names s2bands:  ['2_B1', '2_B2', '2_B3', '2_B4', '2_B5', '2_B6', '2_B7', '2_B8', '2_B8A', '2_B9', '2_B11', '2_B12', '3_B1', '3_B2', '3_B3', '3_B4', '3_B5', '3_B6', '3_B7', '3_B8', '3_B8A', '3_B9', '3_B11', '3_B12', '4_B1', '4_B2', '4_B3', '4_B4', '4_B5', '4_B6', '4_B7', '4_B8', '4_B8A', '4_B9', '4_B11', '4_B12', '5_B1', '5_B2', '5_B3', '5_B4', '5_B5', '5_B6', '5_B7', '5_B8', '5_B8A', '5_B9', '5_B11', '5_B12']
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[9], line 175
#     166 tableStd  = formatStd (featureCollection)
#     169 task = ee.batch.Export.table.toDrive(**{
#     170    'collection':tableMean,
#     171    'description':'tableMeanCsvFile',
#     172    'folder': 'earth_engine_demos',
#     173    'fileFormat':'CSV'
#     174 })
# --> 175 task.start()
#     177 task = ee.batch.Export.table.toDrive(**{
#     178    'collection':tableStd,
#     179    'description':'tableStdCsvFile',
#     180    'folder': 'earth_engine_demos',
#     181    'fileFormat':'CSV'
#     182 })
#     183 task.start()
#
# File ~/.local/lib/python3.10/site-packages/ee/batch.py:94, in Task.start(self)
#      92   result = data.exportMap(self._request_id, self.config)
#      93 elif self.task_type == Task.Type.EXPORT_TABLE:
# ---> 94   result = data.exportTable(self._request_id, self.config)
#      95 elif self.task_type == Task.Type.EXPORT_VIDEO:
#      96   result = data.exportVideo(self._request_id, self.config)
#
# File ~/.local/lib/python3.10/site-packages/ee/data.py:1506, in exportTable(request_id, params)
#    1485 """Starts a table export task running.
#    1486
#    1487 This is a low-level method. The higher-level ee.batch.Export.table object
#    (...)
#    1503   If you are using the cloud API, this will be an Operation.
#    1504 """
#    1505 params = params.copy()
# -> 1506 return _prepare_and_run_export(
#    1507     request_id, params,
#    1508     _get_cloud_api_resource().projects().table().export)
#
# File ~/.local/lib/python3.10/site-packages/ee/data.py:1591, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1589     raise ValueError('"requestId" must be a string.')
#    1590 if isinstance(params['expression'], encodable.Encodable):
# -> 1591   params['expression'] = serializer.encode(
#    1592       params['expression'], for_cloud_api=True)
#    1593 num_retries = MAX_RETRIES if request_id else 0
#    1594 return _execute_cloud_call(
#    1595     export_endpoint(project=_get_projects_path(), body=params),
#    1596     num_retries=num_retries)
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:296, in encode(obj, is_compound, for_cloud_api, unbound_name)
#     280 """Serialize an object to a JSON-compatible structure for API calls.
#     281
#     282 Args:
#    (...)
#     292   A JSON-compatible structure representing the input.
#     293 """
#     294 serializer = Serializer(
#     295     is_compound, for_cloud_api=for_cloud_api, unbound_name=unbound_name)
# --> 296 return serializer._encode(obj)
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:79, in Serializer._encode(self, obj)
#      70 """Encodes a top level object to be executed server-side.
#      71
#      72 Args:
#    (...)
#      76   An encoded object ready for JSON serialization.
#      77 """
#      78 if self._for_cloud_api:
# ---> 79   return self._encode_for_cloud_api(obj)
#      80 value = self._encode_value(obj)
#      81 if self._is_compound:
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:97, in Serializer._encode_for_cloud_api(self, obj)
#      95 def _encode_for_cloud_api(self, obj):
#      96   """Encodes an object as an Expression or quasi-Expression."""
# ---> 97   value = self._encode_cloud_object(obj)
#      98   if self._is_compound:
#      99     # Wrap the scopes and final value into an Expression.
#     100     value = _ExpressionOptimizer(value, self._scope).optimize()
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/.local/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/.local/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
#     [... skipping similar frames: Serializer._encode_cloud_object at line 219 (4478 times), ComputedObject.encode_cloud_value at line 150 (4478 times)]
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:219, in Serializer._encode_cloud_object(self, obj)
#     207   result = {
#     208       'functionInvocationValue': {
#     209           'functionName': 'Date',
#    (...)
#     215       }
#     216   }
#     217 elif isinstance(obj, encodable.Encodable):
#     218   # Some objects know how to encode themselves.
# --> 219   result = obj.encode_cloud_value(self._encode_cloud_object)
#     220 elif isinstance(obj, (list, tuple)):
#     221   # Lists are encoded recursively.
#     222   if self._is_compound:
#
# File ~/.local/lib/python3.10/site-packages/ee/computedobject.py:150, in ComputedObject.encode_cloud_value(self, encoder)
#     148   value = self.args[name]
#     149   if value is not None:
# --> 150     encoded_args[name] = {'valueReference': encoder(value)}
#     151 invocation['arguments'] = encoded_args
#     152 return {'functionInvocationValue': invocation}
#
# File ~/.local/lib/python3.10/site-packages/ee/serializer.py:202, in Serializer._encode_cloud_object(self, obj)
#     200 elif obj is None or isinstance(obj, (bool, str)):
#     201   result = {'constantValue': obj}
# --> 202 elif isinstance(obj, numbers.Number):
#     203   result = _cloud_api_utils.encode_number_as_cloud_value(obj)
#     204 elif isinstance(obj, datetime.datetime):
#     205   # A raw date slipped through. Wrap it. Calling ee.Date from here would
#     206   # cause a circular dependency, so we encode it manually.
#
# File /usr/lib/python3.10/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
#%run MapVisualisation.ipynb
my_map = folium.Map(location=[40,-3], zoom_start=5, height=400)
# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)
# Add Land Mask to the map
my_map.add_ee_layer(s2, {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 2500, 'gamma': 1.1}, 'median'      )
my_map.add_ee_layer(bpoint, {},'bpoint')
#my_map.add_ee_layer(bufferredPoints, {},'bufferredPoints')
my_map.add_ee_layer(geometry,{},"geometry")

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())
plugins.Fullscreen().add_to(my_map)

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)

# %%
print ("   ***   EXIT   ***")
