# %%
# %run CSVtoolsPlotToSat.ipynb

# %%
inCsvfile = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean.csv"
outCsvfile ="/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_meansOfBiomes.csv"
col = "fortype2"
outGraphs ="/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_meansOfBiomesGraphs"
outCsvfolder = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/biomes/"
#getMeanSpectralTemporalSignatures(inCsvfile,col,outCsvfile)

inCsvfile = r"C:\Users\mm2705\Documents\Cambridge\Scripts\SpainPlotToSatData\gdrivefolderTest_Spain_r25_2019\MergedCsvs\OnPlot.csv"
outCsvfile = r"C:\Users\mm2705\Documents\Cambridge\Scripts\SpainPlotToSatData\gdrivefolderTest_Spain_r25_2019\MergedCsvs\OnPlotcsv"
getMeanSpectralTemporalSignatures(inCsvfile,col,outCsvfile)
createSpectralTemporalGraphs(outCsvfile,inCsvfile)

import sys
sys.exit()

inDr       = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2018/MergedCsvs/"
inCsv2018  = inDr + "gdrivefolderTest_plot_Spain_r25_2018_mean"
outCsvfile = inDr + "Spain_r25_2018_meanOfmeans.csv"
#getMeanSpectralTemporalSignatures(inCsv2018,col,outCsvfile)

inDr      = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2019/MergedCsvs/"
inCsv2019 = inDr + "gdrivefolderTest_plot234_column_original_BB_mean"
outCsvfile = inDr + "Spain_r25_2019_meanOfmeans.csv"
#getMeanSpectralTemporalSignatures(inCsv2019,col,outCsvfile)

inDr      = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2020/MergedCsvs/"
inCsv2020 = inDr + "gdrivefolderTest_Spain_r25_2020_mean"
outCsvfile = inDr + "Spain_r25_2020_meanOfmeans.csv"
#getMeanSpectralTemporalSignatures(inCsv2020,col,outCsvfile)


#createSpectralTemporalGraphs(outCsvfile,outGraphs)

outBandMeanCsvFromMeans = outCsvfile+"_bandMeans.csv" # .csv is reluctant because it exports two files with extensions "_S1.csv" and "_S2.csv"
#getMeanPerBandfromMeans(outCsvfile,col,outBandMeanCsvFromMeans)

outBandMeansFromPlotToSatOutput = inCsvfile+"_bandMeans.csv" # .csv is reluctant because it exports two files with extensions "_S1.csv" and "_S2.csv"
#getMeanPerBand(inCsvfile,col,outBandMeansFromPlotToSatOutput)

outBandMeanCsvFromMeansWithNDVI = outBandMeanCsvFromMeans + "_withNDVI.csv" 
#addNDVI(outBandMeanCsvFromMeans, outBandMeanCsvFromMeansWithNDVI)  # outBandMeanCsvFromMeans is not the actual name as the file to be read is outBandMeanCsvFromMeans+"_S2.csv"

outBandMeansFromPlotToSatOutputwithNDVI = outBandMeansFromPlotToSatOutput + "_withDVI.csv"
#addNDVI(outBandMeansFromPlotToSatOutput, outBandMeansFromPlotToSatOutputwithNDVI)  # outBandMeansFromPlotToSatOutput is not the actual name as the file to be read is outBandMeanCsvFromMeans+"_S2.csv"

#saveHist(outBandMeansFromPlotToSatOutputwithNDVI, "NDVI", outBandMeansFromPlotToSatOutputwithNDVI+"_hist.jpg") 

#divideDataAccordingLabels(inCsvfile,col,outCsvfolder)


inCsvfile = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean.csv"
OutFolder = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/statisticsNgraphs"
outCsvflewithNDVIs = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_withNDVIs.csv"
outCsvflewithNDVIsMeans = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_withNDVIs_means.csv"
outImg = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_withNDVIs_means.jpg"
#outImgWithStd = "/home/milto/Documents/fieldData/gdrivefolderTest_plot234_column_original_BB/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean_withNDVIs_means_withStd.jpg"
col = "fortype2"
#getAll(inCsvfile,col,OutFolder) 
PlotsIdCol = "PLOTCODE"


NDVIRoot = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/"
inCsvfile2018 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2018/MergedCsvs/gdrivefolderTest_plot_Spain_r25_2018_mean.csv"
outCsvflewithNDVIs2018 =NDVIRoot + "NDVI2018.csv"

inCsvfile2019 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2019/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_mean.csv"
outCsvflewithNDVIs2019 =NDVIRoot + "NDVI2019.csv"

inCsvfile2020 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2020/MergedCsvs/gdrivefolderTest_Spain_r25_2020_mean.csv"
outCsvflewithNDVIs2020 =NDVIRoot + "NDVI2020.csv"

"""
addNDVIpermonth(inCsvfile2018,col,PlotsIdCol,outCsvflewithNDVIs2018)
addNDVIpermonth(inCsvfile2019,col,PlotsIdCol,outCsvflewithNDVIs2019)
addNDVIpermonth(inCsvfile2020,col,PlotsIdCol,outCsvflewithNDVIs2020)
"""

listOfFiles = [outCsvflewithNDVIs2018,outCsvflewithNDVIs2019,outCsvflewithNDVIs2020]
## NDVI
#addNDVIpermonth(inCsvfile,col,outCsvflewithNDVIs)
#getMeanNDVIsPerMonthForClass(outCsvflewithNDVIs,col,PlotsIdCol,outCsvflewithNDVIsMeans)

outFileAves = NDVIRoot + "aveNDVIs_thres2.csv"
#aveCsvFiles(listOfFiles, col, PlotsIdCol, outFileAves,2)

pathLoc = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/average/"
listOfFiles = [pathLoc+"gdrivefolderTest_plot_Spain_r25_2018_mean.csv", 
               pathLoc+"gdrivefolderTest_plot_Spain_r25_2019_mean.csv",
               pathLoc+"gdrivefolderTest_plot_Spain_r25_2020_mean.csv"]
outfile = pathLoc+"plot_Spain_2018-20_mean_mean_noRowsRemoved.csv"
thres   = 150
#aveCsvFiles(listOfFiles, "fortype2", PlotsIdCol, outfile, thres)





outCsvFile = pathLoc + "plot_Spain_2018-20_mean_mean_withNDVI.csv"
#addNDVIpermonth(outfile,col,PlotsIdCol,outCsvFile)
inFile = outfile
inFile = pathLoc+"gdrivefolderTest_plot_Spain_r25_2018_mean.csv"
outCsvfile = pathLoc + "plot_Spain_2018-20_mean_mean_meanSpetralTemporal_2018.csv"
outFilestart = pathLoc + "plot_2018_fixed"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)
inFile = pathLoc+"gdrivefolderTest_plot_Spain_r25_2019_mean.csv"
outCsvfile = pathLoc + "plot_Spain_2018-20_mean_mean_meanSpetralTemporal_2019.csv"
outFilestart = pathLoc + "plot_2019_fixed"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)
inFile = pathLoc+"gdrivefolderTest_plot_Spain_r25_2020_mean.csv"
outCsvfile = pathLoc + "plot_Spain_2018-20_mean_mean_meanSpetralTemporal_2020.csv"
outFilestart = pathLoc + "plot_2020_fixed"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)

inFile = outfile
outCsvfile = pathLoc + "plot_Spain_2018-20_mean_mean_meanSpetralTemporal_2018-2020.csv"
#outFilestart = pathLoc + "plot_Spain_2018-20_mean_mean_meanSpetralTemporal_2018_2020_fixed"    # SOMETHING WRONG IN THIS LINE                                                                                                                                                                                                                                                                                     2020"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)

dir = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/meanOfmeans/"
inCsvFiles = [ dir+"Spain_r25_2018_meanOfmeansS1.csv", dir + "Spain_r25_2019_meanOfmeansS1.csv", dir+"Spain_r25_2020_meanOfmeansS1.csv"]
outFile = dir + "temporalS13x3graphs.jpeg"
outFileS2 = dir + "temporalS13x3graphsS2ss.jpeg"
row_labels  = ["bldec","bleve", "nleve"]

# createMultiTemporalGraphsFromMultipleFiles(inCsvFiles,outFile)
inCsvFiles = [ dir+"Spain_r25_2018_meanOfmeansS2.csv", dir + "Spain_r25_2019_meanOfmeansS2.csv", dir+"Spain_r25_2020_meanOfmeansS2.csv"]
createMultiSpectralTemporalGraphsSurface(inCsvFiles, outFileS2)
#createMultiSpectralTemporalGraphsSurface(inCsvFiles, outFileS2)



inCsvfile = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r50_2019/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_r50_mean.csv"
outCsvfile = dir + "Spain_r50_2019_meanOfmeans"
#getMeanSpectralTemporalSignatures(inCsvfile,col,outCsvfile)
inCsvfile = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r100_2019/MergedCsvs/gdrivefolderTest_plot234_column_original_BB_r100_mean.csv"
outCsvfile = dir + "Spain_r100_2019_meanOfmeans"
#getMeanSpectralTemporalSignatures(inCsvfile,col,outCsvfile)

inCsvFilesS1 = [dir+"Spain_r25_2019_meanOfmeansS1.csv",dir+"Spain_r50_2019_meanOfmeansS1.csv",dir+"Spain_r100_2019_meanOfmeansS1.csv" ]
inCsvFilesS2 = [dir+"Spain_r25_2019_meanOfmeansS2.csv",dir+"Spain_r50_2019_meanOfmeansS2.csv",dir+"Spain_r100_2019_meanOfmeansS2.csv" ]
outFileS2 = dir + "multiRadiusS2.jpg"
outFileS1 = dir + "multiRadiusS1.jpg"
createMultiSpectralTemporalGraphsSurface(inCsvFilesS2, outFileS2)
#createMultiTemporalGraphsFromMultipleFiles(inCsvFilesS1,outFileS1)

#createGraphOfNDVIs(outCsvflewithNDVIsMeans,col,outImg)
#getMonthForBetterDistingishingClasses(outCsvflewithNDVIsMeans,col)

# not working
#creatGraphOfNDVIsWithStd(outCsvflewithNDVIsMeans,col,outImgWithStd)

#getExecutionTimeStats()


"""
location = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/average/50n100/"
inFile = location+"gdrivefolderTest_plot234_column_original_BB_r50_mean.csv"
outCsvfile = location +"r50_mean_2019.csv"
outFilestart = location +"r50_mean_2019"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)

location = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/average/50n100/"
inFile = location+"gdrivefolderTest_plot234_column_original_BB_r100_mean.csv"
outCsvfile = location +"r100_mean_2019.csv"
outFilestart = location +"r100_mean_2019"
#getMeanSpectralTemporalSignatures(inFile,col,outCsvfile)
#createSpectralTemporalGraphs(outCsvfile,outFilestart)



# REDOING HISTOGRAMS
directory = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2019/MergedCsvs/"
inCsvfile = directory + "gdrivefolderTest_plot234_column_original_BB_mean_withNDVIs.csv"
outCsvfolder = directory + "biomesWithNDVI/"
#divideDataAccordingLabels(inCsvfile,col,outCsvfolder)
"""
"""
inCsvfile = outCsvfolder + "bldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist)
inCsvfile = outCsvfolder + "nleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist)
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist)
inCsvfile = outCsvfolder + "nldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "mixed.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 

directory  = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2020/MergedCsvs/"
inCsvfile  = directory + "gdrivefolderTest_Spain_r25_2020_mean.csv"
outCsvFile = directory + "gdrivefolderTest_Spain_r25_2020_mean_NDVIs.csv" 
outCsvfolder = directory + "biomesWithNDVI/"
addNDVIpermonth(inCsvfile,col,PlotsIdCol,outCsvFile)
divideDataAccordingLabels(outCsvFile,col,outCsvfolder)
inCsvfile = outCsvfolder + "bldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "mixed.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 

directory  = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2018/MergedCsvs/"
inCsvfile  = directory + "gdrivefolderTest_plot_Spain_r25_2018_mean.csv"
outCsvFile = directory + "gdrivefolderTest_plot_Spain_r25_2018_mean_NDVIs.csv" 
outCsvfolder = directory + "biomesWithNDVI/"
addNDVIpermonth(inCsvfile,col,PlotsIdCol,outCsvFile)
divideDataAccordingLabels(outCsvFile,col,outCsvfolder)
inCsvfile = outCsvfolder + "bldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nleve.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nldec.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "mixed.csv"
outHist = inCsvfile +"_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
"""

inDir2018 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2018/MergedCsvs/biomesWithNDVI/"
inDir2019 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2019/MergedCsvs/biomesWithNDVI/"
inDir2020 = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r25_2020/MergedCsvs/biomesWithNDVI/"
inDir = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/"
inCsvFiles = [inDir2018+"bldec.csv", inDir2019+"bldec.csv", inDir2020+"bldec.csv",
              inDir2018+"bleve.csv", inDir2019+"bleve.csv", inDir2020+"bleve.csv",
              inDir2018+"nleve.csv", inDir2019+"nleve.csv", inDir2020+"nleve.csv",]
outHist = inDir+"multiHist4.jpeg"
row_labels = ['broad-leaved deciduous', 'broad-leaved evergreen', 'needle-leaved evergreen']
col_labels = ['2018', '2019', '2020']
#saveMultiHist(inCsvFiles, "6_NDVI", outHist)
inDir = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/biomes/"
inCsvFiles = [inDir2019+"bldec.csv", inDir+"bldec_r50_2019.csv", inDir+"bldec_r100_2019.csv",
              inDir2019+"bleve.csv", inDir+"bleve_r50_2019.csv", inDir+"bleve_r100_2019.csv",
              inDir2019+"nleve.csv", inDir+"nleve_r50_2019.csv", inDir+"nleve_r100_2019.csv",]
outHist = inDir+"multiHistMultiRadius.jpeg"
row_labels = ['broad-leaved deciduous', 'broad-leaved evergreen', 'needle-leaved evergreen']
col_labels = ['Histogram of NDVI July values - Plot radius=25m', 'Histogram of NDVI July values - Plot radius=50m', 'Histogram of NDVI July values - Plot radius=100m']
saveMultiHist(inCsvFiles, "6_NDVI", outHist, row_labels, col_labels)

"""

directory  = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r50_2019/MergedCsvs/"
inCsvfile  = directory + "gdrivefolderTest_plot234_column_original_BB_r50_mean.csv"
outCsvFile = directory + "gdrivefolderTest_plot_Spain_r50_2019_mean_NDVIs.csv" 
outCsvfolder = directory + "biomesWithNDVI/"
addNDVIpermonth(inCsvfile,col,PlotsIdCol,outCsvFile)
divideDataAccordingLabels(outCsvFile,col,outCsvfolder)
inCsvfile = outCsvfolder + "bldec.csv"
outHist = inCsvfile +"_r50_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_r50_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nleve.csv"
outHist = inCsvfile +"_r50_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nldec.csv"
outHist = inCsvfile +"_r50_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "mixed.csv"
outHist = inCsvfile +"_r50_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 

directory  = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/gdrivefolderTest_Spain_r100_2019/MergedCsvs/"
inCsvfile  = directory + "gdrivefolderTest_plot234_column_original_BB_r100_mean.csv"
outCsvFile = directory + "gdrivefolderTest_plot_Spain_r100_2019_mean_NDVIs.csv" 
outCsvfolder = directory + "biomesWithNDVI/"
addNDVIpermonth(inCsvfile,col,PlotsIdCol,outCsvFile)
divideDataAccordingLabels(outCsvFile,col,outCsvfolder)
inCsvfile = outCsvfolder + "bldec.csv"
outHist = inCsvfile +"_r100_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "bleve.csv"
outHist = inCsvfile +"_r100_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nleve.csv"
outHist = inCsvfile +"_r100_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "nldec.csv"
outHist = inCsvfile +"_r100_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
inCsvfile = outCsvfolder + "mixed.csv"
outHist = inCsvfile +"_r100_2019_hist.jpg"
saveHist(inCsvfile, "6_NDVI", outHist) 
"""
# Out:
# ['fortype2', '0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# ...
