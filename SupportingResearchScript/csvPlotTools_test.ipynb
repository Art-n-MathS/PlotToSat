# %%
# %run csvPlotTools.ipynb

# %%
location = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/"
infilename = location + "tree234_columns.csv"
outFileTreeSpecies = location + "treeSpeciesAll.csv"
colSpeciesAll =  "Nombre3.x"
colSpeciesGeneral = "genero3.x"
colPolts = "Plotcode4"
outFilePlotsDominantSpecies = location +  "CountGeneraPerPlot.csv"
outFilePlotsGroupsAll = location + "GroupedSpeciesPlotsWithCountAll.csv"
outFilePlotsGroupsAGeneral = location + "GroupedSpeciesPlotsWithCountGeneral.csv"

outFileMajorColsGeneral = location + "SpeciesinColsWithCountGeneral.csv"
plotsFile =  location + "plot234_column_PenisularSpain.csv"
plotsIDinPlotsFile = "PLOTCODE"


outFilePlotsTopThreeAGeneral = location + "outFilePlotsTopThreeAGeneral.csv"
outfilwithPercentages = location + "CountGeneraPerPlotWithPercentages.csv"
plotsIDperGenusOutFolder = location + "Genera"
#exportUniqueValuesInColumn(infilename,colSpeciesAll,outFileTreeSpecies)
#exportPlotsWithDominantSpecies(infilename,colPolts,plotsFile, plotsIDinPlotsFile,colSpeciesGeneral,outFilePlotsDominantSpecies)
#getPercentageOfSpeciesPerPlot(outFilePlotsDominantSpecies,outfilwithPercentages)
#getPlotIDsPerClass(outfilwithPercentages,colPolts,plotsIDperGenusOutFolder)

outFilePlotsTopThreeASpecies = location + "outFilePlotsTopThreeASpecies.csv"
outfilwithPercentagesSpecies = location + "CountSpeciesPerPlotWithPercentages.csv"
plotsIDperSpeciesOutFolder = location + "Species"
#exportPlotsWithDominantSpecies(infilename,colPolts,plotsFile, plotsIDinPlotsFile,colSpeciesAll,outFilePlotsTopThreeASpecies)
#getPercentageOfSpeciesPerPlot(outFilePlotsTopThreeASpecies,outfilwithPercentagesSpecies)
#getPlotIDsPerClass(outfilwithPercentagesSpecies,colPolts, plotsIDperSpeciesOutFolder)


#groupAndExportCountToCSV(infilename,colPolts,colSpeciesAll,plotsFile, plotsIDinPlotsFile,outFilePlotsGroupsAll)
#groupAndExportCountToCSV(infilename,colPolts,colSpeciesGeneral,plotsFile, plotsIDinPlotsFile,outFilePlotsGroupsAGeneral)
"""
inDir  = location + "Genera/100/NDVIs"
outCsv = location + "Genera/NDVIsLineCount100.csv"
readFilesAndExportCountPerClassToCSV(inDir,outCsv)

inDir  = location + "Genera/75/NDVIs"
outCsv = location + "Genera/NDVIsLineCount75.csv"
readFilesAndExportCountPerClassToCSV(inDir,outCsv)

inDir  = location + "Genera/50/NDVIs"
outCsv = location + "Genera/NDVIsLineCount50.csv"
readFilesAndExportCountPerClassToCSV(inDir,outCsv)
"""

"""
directoryPath =location + "Species/100"
outputFile = location + "Species/Statsfor100.csv"
exportCsvSummary(directoryPath, outputFile)
directoryPath =location + "Species/75"
outputFile = location + "Species/Statsfor75.csv"
exportCsvSummary(directoryPath, outputFile)
directoryPath =location + "Species/50"
outputFile = location + "Species/Statsfor50.csv"
exportCsvSummary(directoryPath, outputFile)

directoryPath =location + "Genera/100"
outputFile = location + "Genera/Statsfor100.csv"
exportCsvSummary(directoryPath, outputFile)
directoryPath =location + "Genera/75"
outputFile = location + "Genera/Statsfor75.csv"
exportCsvSummary(directoryPath, outputFile)
directoryPath =location + "Genera/50"
outputFile = location + "Genera/Statsfor50.csv"
exportCsvSummary(directoryPath, outputFile)

directoryPath =location + "Genera/50-75"
outputFile = location + "Genera/Statsfor50-75.csv"
exportCsvSummary(directoryPath, outputFile)
directoryPath =location + "Genera/75-100"
outputFile = location + "Genera/Statsfor75-100.csv"
exportCsvSummary(directoryPath, outputFile)
"""

"""
directoryPath =location + "Genera/100"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Genera/100/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Genera/75"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Genera/75/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Genera/50"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Genera/50/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)

directoryPath =location + "Species/100"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Species/100/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Species/75"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Species/75/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Species/50"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Species/50/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)

directoryPath =location + "Genera/50-75"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Genera/50-75/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Genera/75-100"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Genera/75-100/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)

directoryPath =location + "Species/50-75"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Species/50-75/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
directoryPath =location + "Species/75-100"
aveNDVIs = "C:/Users/mm2705/Documents/Cambridge/Scripts/SpainPlotToSatData/NDVIs/aveNDVIs.csv"
outFolder = location + "Species/75-100/NDVIs"
filter_rows_by_plot_ids(directoryPath, aveNDVIs, plotsIDinPlotsFile, outFolder)
"""



"""
### Quercus Merging 50-75 & 75-100 - to create this file needs manual modification in code
Qevergreen = "QuercusEvergreen"
directoryPath = location + "/Species/50-75/Quercus/Evergreen"
outputFile = location + "Genera/50-75/QuercusEvergreen.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)
directoryPath = location + "/Species/75-100/Quercus/Evergreen"
outputFile = location + "Genera/75-100/QuercusEvergreen.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)

Qdeciduous = "QuercusDeciduous"
directoryPath = location + "/Species/50-75/Quercus/Deciduous"
outputFile = location + "Genera/50-75/QuercusDeciduous.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)
directoryPath = location + "/Species/75-100/Quercus/Deciduous"
outputFile = location + "Genera/75-100/QuercusDeciduous.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)

"""
"""
### Quercus Merging  50 75 100
Qevergreen = "QuercusEvergreen"
directoryPath = location + "/Species/75/Quercus/Evergreen"
outputFile = location + "Genera/75/QuercusEvergreen.csv" 
mergeCsvFiles(directoryPath, outputFile, Qevergreen)
directoryPath = location + "/Species/50/Quercus/Evergreen"
outputFile = location + "Genera/50/QuercusEvergreen.csv" 
mergeCsvFiles(directoryPath, outputFile, Qevergreen)
directoryPath = location + "/Species/100/Quercus/Evergreen"
outputFile = location + "Genera/100/QuercusEvergreen.csv" 
mergeCsvFiles(directoryPath, outputFile, Qevergreen)
Qdeciduous = "QuercusDeciduous"
directoryPath = location + "/Species/75/Quercus/Deciduous"
outputFile = location + "Genera/75/QuercusDeciduous.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)
directoryPath = location + "/Species/50/Quercus/Deciduous"
outputFile = location + "Genera/50/QuercusDeciduous.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)
directoryPath = location + "/Species/100/Quercus/Deciduous"
outputFile = location + "Genera/100/QuercusDeciduous.csv" 
mergeCsvFiles(directoryPath, outputFile, Qdeciduous)
"""
"""
inDir = location + "Genera/100/NDVIs"
classList = ["Pinus", "QuercusEvergreen", "QuercusDeciduous", "Fagus", "Eucalyptus", "Juniperus"] 
noOfSamples = 236
outCsv = location + "Genera/DominantGenus100_236Samples.csv" 
selectSamples(inDir,classList,noOfSamples,outCsv)

inDir = location + "Genera/75-100/NDVIs"
noOfSamples = 50
outCsv = location + "Genera/DominantGenus75-100_50Samples.csv" 
selectSamples(inDir,classList,noOfSamples,outCsv)

inDir = location + "Genera/50-75/NDVIs"
noOfSamples = 54
outCsv = location + "Genera/DominantGenus50-75_54Samples.csv" 
selectSamples(inDir,classList,noOfSamples,outCsv)
"""


# Merge samples
directory_path = location + "Genera\samples" # Manually moved here
output_file = directory_path + "\DominantGenusAllSamples.csv"

new_column_label = "Unnamed: 0.1,Unnamed: 0,fortype2,PLOTCODE,0_NDVI,1_NDVI,2_NDVI,3_NDVI,4_NDVI,5_NDVI,6_NDVI,7_NDVI,8_NDVI,9_NDVI,10_NDVI,11_NDVI,class"
#mergeCsvFiles(directory_path, output_file, new_column_label) # Run in a clean folder - only containing files to be merged
"""
# Add coordinates to samples using PlotIDs
inFile = directory_path + "\DominantGenusAllSamples.csv"
outfile = directory_path + "\DominantGenusAllSamplesWithCoordinates.csv"
print("Start")
addCoordinates(inFile,plotsFile,plotsIDinPlotsFile,"CX","CY",outfile)  #"CX","CY" the names of the columns to be added
print("End")
inFile = directory_path + "\DominantGenus100_236Samples.csv"
outfile = directory_path + "\DominantGenus100_236SamplesWithCoordinates.csv"
addCoordinates(inFile,plotsFile,plotsIDinPlotsFile,"CX","CY",outfile)  #"CX","CY" the names of the columns to be added
"""


outDir = location + "Genera/samples/classes"
inFile = location +  "Genera/samples/DominantGenusAllSamplesWithCoordinates.csv"
classCol = "class"
#divideToSubfiles(inFile, classCol, outDir) # for QGIS visualisation of classes

"""
# Dividing data to three files for testing and training
inCsv = location + "Genera/samples/DominantGenus100_236Samples.csv"
outDir = location + "Genera/samples/DominantGenus100_236Samples"
divideToThreeForCrossValidation(inCsv,outDir)

inCsv = location + "Genera/samples/DominantGenusAllSamples.csv"
outDir = location + "Genera/samples/DominantGenusAllSamples"
divideToThreeForCrossValidation(inCsv,outDir)
"""

inCsv = location + "Genera/samples/ALLDATAsamplesDominantGenusAllSamples.csv"
outDir = location + "Genera/samples/ALLDATAsamplesDominantGenusAllSamples"
#divideToThreeForCrossValidation(inCsv,outDir)

data1 = location +"Genera/samples/DominantGenus100_236Samples/file_1.csv"
data2 = location +"Genera/samples/DominantGenus100_236Samples/file_2.csv"
data3 = location +"Genera/samples/DominantGenus100_236Samples/file_3.csv"
test_results1 = location +"Genera/samples/DominantGenus100_236Samples/file_1_results_k7.csv"
test_results2 = location +"Genera/samples/DominantGenus100_236Samples/file_2_results_k7.csv"
test_results3 = location +"Genera/samples/DominantGenus100_236Samples/file_3_results_k7.csv"
k = 7
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing


#test_results1 = location +"Genera/samples/DominantGenus100_236Samples/file_1_results_k5.csv"
#test_results2 = location +"Genera/samples/DominantGenus100_236Samples/file_2_results_k5.csv"
#test_results3 = location +"Genera/samples/DominantGenus100_236Samples/file_3_results_k5.csv"
k = 5
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two fo

test_results1 = location +"Genera/samples/DominantGenus100_236Samples/file_1_results_k3.csv"
test_results2 = location +"Genera/samples/DominantGenus100_236Samples/file_2_results_k3.csv"
test_results3 = location +"Genera/samples/DominantGenus100_236Samples/file_3_results_k3.csv"
k = 3
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two fo

#test_results1 = location +"Genera/samples/DominantGenus100_236Samples/file_1_results_k9.csv"
#test_results2 = location +"Genera/samples/DominantGenus100_236Samples/file_2_results_k9.csv"
test_results3 = location +"Genera/samples/DominantGenus100_236Samples/file_3_results_k9.csv"
k = 9
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two fo



data1 = location +"Genera/samples/DominantGenusAllSamples/file_1.csv"
data2 = location +"Genera/samples/DominantGenusAllSamples/file_2.csv"
data3 = location +"Genera/samples/DominantGenusAllSamples/file_3.csv"
k=9
test_results1 = location +"Genera/samples/DominantGenusAllSamples/file_1_results_9.csv"
test_results2 = location +"Genera/samples/DominantGenusAllSamples/file_2_results_9.csv"
test_results3 = location +"Genera/samples/DominantGenusAllSamples/file_3_results_9.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing
output_file = test_results1 + "eval.csv"
#calculate_and_save_metrics(test_results1, "class", "Results", output_file)

k=7
test_results1 = location +"Genera/samples/DominantGenusAllSamples/file_1_results_7.csv"
test_results2 = location +"Genera/samples/DominantGenusAllSamples/file_2_results_7.csv"
test_results3 = location +"Genera/samples/DominantGenusAllSamples/file_3_results_7.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing


k=5
test_results1 = location +"Genera/samples/DominantGenusAllSamples/file_1_results_5.csv"
test_results2 = location +"Genera/samples/DominantGenusAllSamples/file_2_results_5.csv"
test_results3 = location +"Genera/samples/DominantGenusAllSamples/file_3_results_5.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing
output_file = test_results1 + "eval.csv"
calculate_and_save_metrics(test_results1, "class", "Results", output_file)


k=3
test_results1 = location +"Genera/samples/DominantGenusAllSamples/file_1_results_3.csv"
test_results2 = location +"Genera/samples/DominantGenusAllSamples/file_2_results_3.csv"
test_results3 = location +"Genera/samples/DominantGenusAllSamples/file_3_results_3.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing


###### ALLDATAsamplesDominantGenusAllSamples
k=9
data1 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_1.csv"
data2 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2.csv"
data3 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3.csv"
test_results1 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_1_results_9.csv"
test_results2 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2_results_9.csv"
test_results3 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3_results_9.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing

#calculate_and_save_metrics(test_results1, "class", "Results", test_results1 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results2 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results3 + "eval.csv")

k=7
test_results1 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_1_results_7.csv"
test_results2 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2_results_7.csv"
test_results3 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3_results_7.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing

#calculate_and_save_metrics(test_results1, "class", "Results", test_results1 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results2 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results3 + "eval.csv")


k=5
test_results1 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_1_results_5.csv"
test_results2 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2_results_5.csv"
test_results3 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3_results_5.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing

#calculate_and_save_metrics(test_results1, "class", "Results", test_results1 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results2 + "eval.csv")
#calculate_and_save_metrics(test_results1, "class", "Results", test_results3 + "eval.csv")


k=3
test_results1 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_1_results_3.csv"
test_results2 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2_results_3.csv"
test_results3 = location +"Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3_results_3.csv"
#classifyKNN (data1, data2, data3, test_results3, k) # first two for training, third one for testing
#classifyKNN (data1, data3, data2, test_results2, k) # first two for training, third one for testing
#classifyKNN (data3, data2, data1, test_results1, k) # first two for training, third one for testing


calculate_and_save_metrics(test_results1, "class", "Results", test_results1 + "eval.csv")
calculate_and_save_metrics(test_results1, "class", "Results", test_results2 + "eval.csv")
calculate_and_save_metrics(test_results1, "class", "Results", test_results3 + "eval.csv")


dirFT = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/forestTypesCsvs/"
infilename_nleve = dirFT + "nleve_p.csv"
infilename_bleve = dirFT + "bleve_p.csv"
infilename_bldec = dirFT + "bldec_p.csv"
outFile_nleve = dirFT + "nleve_species.csv"
outFile_bldec = dirFT + "bldec_species.csv"
outFile_bleve = dirFT + "bleve_species.csv"
# infilename tree234_columns.csv
colPoltsP = "PLOTCODE"
colPoltsS = "Plotcode4"
#exportUniqueValuesInColumnOfPlots(infilename,colSpeciesAll, colPoltsS, infilename_nleve, colPoltsP, outFile_nleve)
#exportUniqueValuesInColumnOfPlots(infilename,colSpeciesAll, colPoltsS, infilename_bleve, colPoltsP, outFile_bleve)
#exportUniqueValuesInColumnOfPlots(infilename,colSpeciesAll, colPoltsS, infilename_bldec, colPoltsP, outFile_bldec)
# Out:
#               Class   TP   TN  FP  FN  Precision    Recall  F1 Score
# 0        Eucalyptus   64  515  51  50   0.556522  0.561404  0.558952
# 1             Fagus  105  546  20   9   0.840000  0.921053  0.878661
# 2         Juniperus   86  511  57  26   0.601399  0.767857  0.674510
# 3             Pinus   48  500  66  66   0.421053  0.421053  0.421053
# 4  QuercusDeciduous   70  535  31  44   0.693069  0.614035  0.651163
# 5  QuercusEvergreen   37  523  45  75   0.451220  0.330357  0.381443
# File saved in  C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/Genera/samples/DominantGenusAllSamples/file_1_results_5.csveval.csv
# Classified results are given in  C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_3_results_9.csv
# Classified results are given in  C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/Genera/samples/ALLDATAsamplesDominantGenusAllSamples/file_2_results_9.csv
# ...
