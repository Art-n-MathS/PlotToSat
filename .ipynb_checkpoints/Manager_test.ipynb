# %%
# Include these lines in tests and comment out Authenticate after the first use to avoid 
# authenticate at each run.
import ee
#ee.Authenticate()
ee.Initialize()
import sys
# %run Manager.ipynb


# By default recursion is 1000. By increasing it you can handling more plot data at once 
# but you are doing it at your own risk 
sys.setrecursionlimit(9000)

print("hello")

countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
geometry = countries.filter(ee.Filter.eq('country_na', 'Spain'))

# Define a geometry as small as possible containing your area of interest
#geometry = ee.Geometry.Polygon(
#    [[[-5.586640856054208, 40.07176423657564],
#      [-5.391633531835458, 40.07176423657564],
#      [-5.391633531835458, 40.17257546939766],
#      [-5.6106734488276455, 40.170476760191924]]])

# Example locations of test plot data
csvFile = "/home/milto/Documents/FLFScripts/sampleData/plot234_column.csv"
#csvFile = "/home/milto/Documents/FLFScripts/sampleData/samplePlots.csv"

# Define the field data as a dictionary using these three compulsory fields
# 'csvfilename'   : name of csv file containing the plot data with its path directory 
# 'proj'          : the projection of the plot data
# 'radius'        : the radius of the plot data that is consistent across all of them
fieldData = {
    'csvfilename'   :csvFile,
    'proj'          :"EPSG:3042",
    'radius'        :30
    }

# Create a manager
myManager = Manager(geometry,fieldData,"CX", "CY",2017)

## With this command you can see all the supported collections and the associated 
## labels that you need to use to add the data into the manager
myManager.printAvailableCollections()


# Adding masks is optional. You may add none from multiple masks as follow. 
# If no masks are set then no masks are applied
# masks={}
masks = {
    'gsw': 30, 
    'lmask': 30, 
    'forestMask': {
        'buffer':30, 
        'startDate':'2000-01-01', 
        'endDate':'2017-12-31'}
        } #,'aspectDes':0,'aspectAsc':0}
myManager.setMasks(masks)
#myManager.setYear(2022)

# GEE cannot handle long csv files so the system allows you to break processing into 
# smaller samples. The size is user defined and there is a script that once all sub-samples 
# are exported the user can use to merge them.
myManager.setSampling(500)

## the addCollection command adds a collection to the manager
## It takes as input the label of the collection and a variable
myManager.addCollection('sentinel-1', False) # False for not using the aspect maps
myManager.addCollection('sentinel-2',50    ) # 50 for cloud percentage

myManager.exportFeatures("gdrivefolder", "featurevectors2017csvFilemasks1")
# Out:
# Utils imported
# Masks class imported
# GEE already imported
# Sentinel1 class imported
# Sentinel2b class imported
# GEE already imported
# Class fieldData imported
# Masks class imported
# hello
# exporting field data to  FieldDataWithIdentifiers.csv
# /tmp/ipykernel_376358/1661703581.py:18: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.df = pd.read_csv(csvFileName)
# Sentinel1:  2017-01-01 2017-12-31
# Sentinel2:  2017-01-01 2017-12-31
# There are  2  collections available within the system:
#         label                   collection
# 0  sentinel-1            COPERNICUS/S1_GRD
# 1  sentinel-2  COPERNICUS/S2_SR_HARMONIZED
# NEW SAMPLING: =  500
# Sentinel 1 added
# Sentinel 2 added
# Start exporting features 1
# Start exporting features 2
# 0 500 51928
# 0000000000 0000000499 51928 featurevectors2017csvFilemasks1_0000000000_0000000499
# 0000000500 0000000999 51928 featurevectors2017csvFilemasks1_0000000500_0000000999
# 0000001000 0000001499 51928 featurevectors2017csvFilemasks1_0000001000_0000001499
# 0000001500 0000001999 51928 featurevectors2017csvFilemasks1_0000001500_0000001999
# 0000002000 0000002499 51928 featurevectors2017csvFilemasks1_0000002000_0000002499
# 0000002500 0000002999 51928 featurevectors2017csvFilemasks1_0000002500_0000002999
# 0000041500 0000041999 51928 featurevectors2017csvFilemasks1_0000041500_0000041999
# 0000042000 0000042499 51928 featurevectors2017csvFilemasks1_0000042000_0000042499
# 0000042500 0000042999 51928 featurevectors2017csvFilemasks1_0000042500_0000042999
# 0000043000 0000043499 51928 featurevectors2017csvFilemasks1_0000043000_0000043499
# 0000043500 0000043999 51928 featurevectors2017csvFilemasks1_0000043500_0000043999
# 0000044000 0000044499 51928 featurevectors2017csvFilemasks1_0000044000_0000044499
# 0000044500 0000044999 51928 featurevectors2017csvFilemasks1_0000044500_0000044999
# 0000045000 0000045499 51928 featurevectors2017csvFilemasks1_0000045000_0000045499
# 0000045500 0000045999 51928 featurevectors2017csvFilemasks1_0000045500_0000045999
# 0000046000 0000046499 51928 featurevectors2017csvFilemasks1_0000046000_0000046499
# 0000046500 0000046999 51928 featurevectors2017csvFilemasks1_0000046500_0000046999
# 0000047000 0000047499 51928 featurevectors2017csvFilemasks1_0000047000_0000047499
# 0000047500 0000047999 51928 featurevectors2017csvFilemasks1_0000047500_0000047999
# 0000048000 0000048499 51928 featurevectors2017csvFilemasks1_0000048000_0000048499
# 0000048500 0000048999 51928 featurevectors2017csvFilemasks1_0000048500_0000048999
# 0000049000 0000049499 51928 featurevectors2017csvFilemasks1_0000049000_0000049499
# 0000049500 0000049999 51928 featurevectors2017csvFilemasks1_0000049500_0000049999
# 0000050000 0000050499 51928 featurevectors2017csvFilemasks1_0000050000_0000050499
# 0000050500 0000050999 51928 featurevectors2017csvFilemasks1_0000050500_0000050999
# 0000051000 0000051499 51928 featurevectors2017csvFilemasks1_0000051000_0000051499
# 0000051500 0000051999 51928 featurevectors2017csvFilemasks1_0000051500_0000051999
# FORCED EXIT
# 2017-01-01 2017-12-31 True
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# exporting field data to  featurevectors2017csvFilemasks1_0000051500_0000051999_S1.csv
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 72
#      69 myManager.addCollection('sentinel-1', False) # False for not using the aspect maps
#      70 myManager.addCollection('sentinel-2',50    ) # 50 for cloud percentage
# ---> 72 myManager.exportFeatures("gdrivefolder", "featurevectors2017csvFilemasks1")
#
# File /tmp/ipykernel_376358/1731544929.py:238, in Manager.exportFeatures(self, gdrivefolder, startOffeaturesFilename)
#     236         s1.byMonth(lys)
#     237         s1bands = s1.getCollectionToBands()
# --> 238         self.csvDF.exportFeaturesMeanStdCSV(s1bands,startOffeaturesFilenamesWithSampling+"_S1",gdrivefolder)
#     240 else:
#     241     print("WARNING: Sentinel 1 collection parameters loaded are NOT valid and system is skipping this collection")
#
# File /tmp/ipykernel_376358/1661703581.py:237, in FieldData.exportFeaturesMeanStdCSV(self, collection, ouutCsvFeatureVectors, driveFolder)
#     234 self.exportPlotDataWithAddedIdentifiers(ouutCsvFeatureVectors+".csv")
#     236 if (self.bufferredPoints == None):
# --> 237     raise Exception("Please call createBufferedPoints(xlabel, ylabel, r) function first" )
#     238 featureCollection = self.getFeatureCollection(collection,self.bufferredPoints)
#     240 tableMean = self.formatMean(featureCollection)
#
# Exception: Please call createBufferedPoints(xlabel, ylabel, r) function first
