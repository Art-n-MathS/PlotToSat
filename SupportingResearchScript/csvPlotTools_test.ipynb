# %%
# %run csvPlotTools.ipynb

# %%
location = "C:/Users/mm2705/Documents/Cambridge/Milto_SPSW/L1/Spain/"
infilename = location + "plot234_column_PenisularSpain.csv"
outFileTreeSpecies = location + "treeSpeciesAll.csv"
colSpeciesAll =  "Nombre3.x"
colSpeciesGeneral = "genero3.x"
colPolts = "Plotcode4"
outFilePlotsDominantSpecies = location +  "CountGeneraPerPlot.csv"
outFilePlotsGroupsAll = location + "GroupedSpeciesPlotsWithCountAll.csv"
outFilePlotsGroupsAGeneral = location + "GroupedSpeciesPlotsWithCountGeneral.csv"

outFileMajorColsGeneral = location + "SpeciesinColsWithCountGeneral.csv"


outFilePlotsTopThreeAGeneral = location + "outFilePlotsTopThreeAGeneral.csv"
outfilwithPercentages = location + "CountGeneraPerPlotWithPercentages.csv"
plotsIDperGenusOutFolder = location + "Genera"
#exportUniqueValuesInColumn(infilename,colSpeciesAll,outFileTreeSpecies)
#exportPlotsWithDominantSpecies(infilename,colPolts,colSpeciesGeneral,outFilePlotsDominantSpecies)
#getPercentageOfSpeciesPerPlot(outFilePlotsDominantSpecies,outfilwithPercentages)
getPlotIDsPerClass(outfilwithPercentages,colPolts,plotsIDperGenusOutFolder)

outFilePlotsTopThreeASpecies = location + "outFilePlotsTopThreeASpecies.csv"
outfilwithPercentagesSpecies = location + "CountSpeciesPerPlotWithPercentages.csv"
plotsIDperSpeciesOutFolder = location + "Species"
#exportPlotsWithDominantSpecies(infilename,colPolts,colSpeciesAll,outFilePlotsTopThreeASpecies)
#getPercentageOfSpeciesPerPlot(outFilePlotsTopThreeASpecies,outfilwithPercentagesSpecies)
getPlotIDsPerClass(outfilwithPercentagesSpecies,colPolts,plotsIDperSpeciesOutFolder)

#exportTop3SpeciesWithPercentage(infilename,colPolts,colSpeciesAll,outFilePlotsTopThreeAll)
#exportTop3SpeciesWithPercentage(outFilePlotsTopThreeAGeneral,colPolts,colSpeciesGeneral,outFilePlotsTopThreeAGeneral)

#groupAndExportCountToCSV(infilename,colPolts,colSpeciesAll,outFilePlotsGroupsAll)
#groupAndExportCountToCSV(infilename,colPolts,colSpeciesGeneral,outFilePlotsGroupsAGeneral)

#rearrangeGroupsInColumns(outFilePlotsGroupsAll,colPolts,colSpeciesAll,outFileThreeColsAll)


#exportPlotsWithDominantSpeciesAndSelectMostCommonSpecies(outFilePlotsDominantSpecies,colPolts,outFileMajorColsGeneral)

#outFile = outFilePlotsDominantSpecies+"ranked.csv"
#exportTop3SpeciesWithPercentage(outFilePlotsDominantSpecies, colPolts, colSpeciesGeneral, outFile)


#exportPlotsWithDominantSpecies2(outFilePlotsDominantSpecies, colPlots, colSpecies, outFile)
# Out:
# Plots with more than 75% of Abies: [170046, 170050, 250011, 250016, 250017, 250025, 250030, 250037, 250039, 250043, 250044, 250049, 250050, 250073, 250077, 250100, 250111, 250131, 250181, 250187, 250191, 250197, 250271, 250316, 250338, 250345, 250368, 250438, 251516, 481155]
# Plots with more than 75% of Acacia: [270718, 320315, 320714, 360884, 361020, 361665]
# Plots with more than 75% of Acer: [100008, 11112, 171543, 260519, 261115]
# Plots with more than 75% of Alnus: [101174, 102033, 103025, 10652, 150821, 151119, 151868, 151982, 200981, 260160, 271070, 271587, 320214, 320453, 320692, 320767, 321544, 360334, 361569, 480291, 480411, 480895, 490753, 51106]
# Plots with more than 75% of Arbutus: [100347, 103077, 11271, 11319, 172870, 272773, 380580, 61152, 61268, 61744]
# ...
