# %%
import sys

# check if GEE is already imported to avoid requesting authenticatiation multiple times
modulename = 'ee'
if modulename not in sys.modules: 
   # import GEE and Authenticate, token or log in will be asked from web browser
   import ee
   ee.Authenticate()
   ee.Initialize()
else:
   print('GEE already imported')
   # google earth engine already imported and authenticated
   
   
# Visualisation
modulename = 'ipynb_MapVisualisation'
if modulename not in sys.modules:
    # %run MapVisualisation.ipynb
    # adding an identifier to sys.modules to avoiding loading the same file multiple times
    sys.modules['ipynb_MapVisualisation'] = None 
#else
   # MapVisualisation module has already been loaded somewhere else
# Out:
# MapVisualisation class imported - uses folium library

# %%
#shapefile added to GEE through the Assets tab
shp = "projects/ee-flf-milto/assets/PlotToSatTestShp"

shpFeatureCollection = ee.FeatureCollection(shp)
lenOfFieldData = shpFeatureCollection.size().getInfo()
print('Number of polygon features:', lenOfFieldData)

min_index = 10  # inclusive
max_index = 20  # exclusive

feature_list = shpFeatureCollection.toList(lenOfFieldData)  # Get the list of features
subset_list = feature_list.slice(min_index, max_index)   # Slice the list

        
# Convert the sliced list back to a FeatureCollection
subset_collection = ee.FeatureCollection(subset_list)
lenOfSubsetCol = subset_collection.size().getInfo()
print("Subset of collection contains ", lenOfSubsetCol, " polygons")

lenOfFieldData = shpFeatureCollection.size().getInfo()
print(lenOfFieldData)
# Out:
# Number of polygon features: 538
# Subset of collection contains  10  polygons
# 538

# %%
# %run MapVisualisation.ipynb


# Set visualization parameters.
vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

# Create a folium map object.
my_map = folium.Map(location=[33,34], zoom_start=6)


# Add custom basemaps
basemaps['Google Maps'].add_to(my_map)
basemaps['Google Satellite Hybrid'].add_to(my_map)


my_map.add_ee_layer(shpFeatureCollection,{},'shp')
my_map.add_ee_layer(subset_collection,{},"shp_subset")



# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())


plugins.Fullscreen().add_to(my_map)

# Add a layer control panel to the map.
my_map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(my_map)

# Display the map.
display(my_map)
# Out:
# MapVisualisation class imported - uses folium library
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e85bf861d3d27921bd3f196ab3cb35f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e85bf861d3d27921bd3f196ab3cb35f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e85bf861d3d27921bd3f196ab3cb35f = L.map(
#                 &quot;map_5e85bf861d3d27921bd3f196ab3cb35f&quot;,
#                 {
#                     center: [33.0, 34.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b94d0752a0569c9cdc9f74675d61a9c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b94d0752a0569c9cdc9f74675d61a9c2.addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#             var tile_layer_51ce17582c96f5a180505cf4e8ccebcb = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51ce17582c96f5a180505cf4e8ccebcb.addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#             var tile_layer_2028b7603111b8009ece8314c7ca003a = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2028b7603111b8009ece8314c7ca003a.addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#             var tile_layer_81c3e2928c7bbf59d84262c07ef600bd = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/253609595081/maps/bc4a2dbab9a6d7d3bb19b4341b4d5b49-86fce4c56b1df08d6b4464431ec8cb99/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81c3e2928c7bbf59d84262c07ef600bd.addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#             var tile_layer_854c2c5db2a968bb4f73bc7d7a80a299 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/253609595081/maps/bec08710952e4eecaaa9d211a82a07c5-1a9eea30ac4d51d6b37603a0a7eb47db/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_854c2c5db2a968bb4f73bc7d7a80a299.addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#             var layer_control_7ce048355c8d4170e359e00e07718a89_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b94d0752a0569c9cdc9f74675d61a9c2,
#                 },
#                 overlays :  {
#                     &quot;Google Maps&quot; : tile_layer_51ce17582c96f5a180505cf4e8ccebcb,
#                     &quot;Google Satellite&quot; : tile_layer_2028b7603111b8009ece8314c7ca003a,
#                     &quot;shp&quot; : tile_layer_81c3e2928c7bbf59d84262c07ef600bd,
#                     &quot;shp_subset&quot; : tile_layer_854c2c5db2a968bb4f73bc7d7a80a299,
#                 },
#             };
#             let layer_control_7ce048355c8d4170e359e00e07718a89 = L.control.layers(
#                 layer_control_7ce048355c8d4170e359e00e07718a89_layers.base_layers,
#                 layer_control_7ce048355c8d4170e359e00e07718a89_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
#
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_5e85bf861d3d27921bd3f196ab3cb35f);
