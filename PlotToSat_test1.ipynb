# %%
# import all the necessary libraries
# %run PlotToSat.ipynb

# Define study region
polygon = ee.Geometry.Polygon(
[[[-6.7820312500000135, 37.744682241748094],
[-1.1570312500000135, 37.32651387565316],
[0.1613281249999865, 42.25294129803316],
[-7.3093750000000135, 43.349172765639516]]])

# Create a dictionary that holds the relevant plot information
fieldData = {
       "csvfilename"         : r"./samplePlots.csv",
       "proj"                : "EPSG:3042",
       "radius"              : 30,
       "xcol"                : "CX",    
       "ycol"                : "CY",
       "outPlotFileWithIDs"  : r"plotsWithIDs\SpainIDs_1.csv"
}

# Specify the year of interest
year = 2019

# Create an instance of the Manager
myPlotToSat = PlotToSat(polygon,fieldData,year) 

# Add Earth Observation Collections of interest
myPlotToSat.addCollection("sentinel-1", True) 
myPlotToSat.addCollection("sentinel-2", 50  ) 

#Definition and exportation of outputs
myPlotToSat.exportFeatures("folderSpain1", "outfeaturevectors")
# Out:
# Importing GEE
# Utils imported
# Masks class imported
# GEE already imported
# Sentinel1 class imported
# Sentinel2b class imported
# GEE already imported
# Class fieldData imported
# Masks class imported
# GEE already imported
# Return didn't work
# Sentinel1:  2019-01-01 2019-12-31
# Sentinel2:  2019-01-01 2019-12-31
# Sentinel 1 added
# Sentinel 2 added
# Self.sampling size  400
# Creating Circular plots
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# <>:27: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\mm1397\AppData\Local\Temp\ipykernel_16856\3022832254.py:27: SyntaxWarning: invalid escape sequence '\c'
#   raise Exception("CSV input file should be defined as follow  '\csvfilename'\:<csvfilename>")
# c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\deprecation.py:207: DeprecationWarning:
#
# Attention required for UMD/hansen/global_forest_change_2022_v1_10! You are using a deprecated asset.
# To ensure continued functionality, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/UMD_hansen_global_forest_change_2022_v1_10
#
#   warnings.warn(warning, category=DeprecationWarning)
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# C:\Users\mm1397\AppData\Local\Temp\ipykernel_16856\3022832254.py:27: SyntaxWarning: invalid escape sequence '\c'
#   raise Exception("CSV input file should be defined as follow  '\csvfilename'\:<csvfilename>")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 32
#      29 myPlotToSat.addCollection("sentinel-2", 50  )
#      31 #Definition and exportation of outputs
# ---> 32 myPlotToSat.exportFeatures("folderSpain1", "outfeaturevectors")
#
# File ~\AppData\Local\Temp\ipykernel_16856\3869951423.py:352, in PlotToSat.exportFeatures(self, gdrivefolder, startOffeaturesFilename)
#     350 if ((self.shp is not None or self.csvDF is not None) and polygons is not None):
#     351     print ("exporting collections")
# --> 352     self.exportCollections(startOffeaturesFilenamesWithSampling,gdrivefolder)
#     353 else :
#     354    print( "WARNING: Skipping exportation as polygons from ", currentMin, " to ", currentMax,
#     355          " haven't been created")
#
# File ~\AppData\Local\Temp\ipykernel_16856\3869951423.py:267, in PlotToSat.exportCollections(self, startOffeaturesFilenamesWithSampling, gdrivefolder)
#     265 s1bandsDes = s1.getCollectionToBandsDes()
#     266 if (self.shp is None):
# --> 267     self.csvDF.exportFeaturesMeanStdCSV(s1bandsAsc,startOffeaturesFilenamesWithSampling+"_S1Asc",gdrivefolder)
#     268     self.csvDF.exportFeaturesMeanStdCSV(s1bandsDes,startOffeaturesFilenamesWithSampling+"_S1Des",gdrivefolder)
#     269 else:
#
# File ~\AppData\Local\Temp\ipykernel_16856\3022832254.py:427, in FieldData.exportFeaturesMeanStdCSV(self, collection, ouutCsvFeatureVectors, driveFolder)
#     419 task.start()
#     421 task = ee.batch.Export.table.toDrive(**{
#     422     'collection':tableStd,
#     423     'description':stdName,
#     424     'folder': driveFolder,
#     425     'fileFormat':'CSV'
#     426 })
# --> 427 task.start()
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\batch.py:149, in Task.start(self)
#     147   result = data.exportMap(self._request_id, self.config)
#     148 elif self.task_type == Task.Type.EXPORT_TABLE:
# --> 149   result = data.exportTable(self._request_id, self.config)
#     150 elif self.task_type == Task.Type.EXPORT_VIDEO:
#     151   result = data.exportVideo(self._request_id, self.config)
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\data.py:1790, in exportTable(request_id, params)
#    1769 """Starts a table export task running.
#    1770
#    1771 This is a low-level method. The higher-level ee.batch.Export.table object
#    (...)
#    1787   If you are using the cloud API, this will be an Operation.
#    1788 """
#    1789 params = params.copy()
# -> 1790 return _prepare_and_run_export(
#    1791     request_id, params, _get_cloud_projects().table().export
#    1792 )
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\data.py:1904, in _prepare_and_run_export(request_id, params, export_endpoint)
#    1902     raise ValueError('"requestId" must be a string.')
#    1903 if isinstance(params['expression'], encodable.Encodable):
# -> 1904   params['expression'] = serializer.encode(
#    1905       params['expression'], for_cloud_api=True)
#    1906 num_retries = _max_retries if request_id else 0
#    1907 return _execute_cloud_call(
#    1908     export_endpoint(project=_get_projects_path(), body=params),
#    1909     num_retries=num_retries)
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:301, in encode(obj, is_compound, for_cloud_api, unbound_name)
#     285 """Serialize an object to a JSON-compatible structure for API calls.
#     286
#     287 Args:
#    (...)
#     297   A JSON-compatible structure representing the input.
#     298 """
#     299 serializer = Serializer(
#     300     is_compound, for_cloud_api=for_cloud_api, unbound_name=unbound_name)
# --> 301 return serializer._encode(obj)
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:79, in Serializer._encode(self, obj)
#      70 """Encodes a top level object to be executed server-side.
#      71
#      72 Args:
#    (...)
#      76   An encoded object ready for JSON serialization.
#      77 """
#      78 if self._for_cloud_api:
# ---> 79   return self._encode_for_cloud_api(obj)
#      80 value = self._encode_value(obj)
#      81 if self._is_compound:
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:100, in Serializer._encode_for_cloud_api(self, obj)
#      97 value = self._encode_cloud_object(obj)
#      98 if self._is_compound:
#      99   # Wrap the scopes and final value into an Expression.
# --> 100   value = _ExpressionOptimizer(value, self._scope).optimize()
#     101   # Clear state in case of future encoding.
#     102   self._scope = []
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:411, in _ExpressionOptimizer.optimize(self)
#     409 def optimize(self) -> Any:
#     410   """Optimises the expression, returning the optimised form."""
# --> 411   optimized_result = self._optimize_referred_value(self._result)
#     412   if self._is_compound():
#     413     return {'result': optimized_result, 'values': self._optimized_values}
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:444, in _ExpressionOptimizer._optimize_referred_value(self, reference_or_value)
#     442   mapped_reference = str(len(self._reference_map))
#     443   self._reference_map[reference_or_value] = mapped_reference
# --> 444   self._optimized_values[mapped_reference] = self._optimize_value(
#     445       self._values[reference_or_value], 0)
#     446   return mapped_reference
#     447 else:
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:523, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     521 referenced_value = self._values[reference]
#     522 if reference in self._single_uses and depth < _DEPTH_LIMIT:
# --> 523   return self._optimize_value(referenced_value, depth)
#     524 else:
#     525   if self._is_always_liftable(referenced_value):
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:523, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     521 referenced_value = self._values[reference]
#     522 if reference in self._single_uses and depth < _DEPTH_LIMIT:
# --> 523   return self._optimize_value(referenced_value, depth)
#     524 else:
#     525   if self._is_always_liftable(referenced_value):
#
#     [... skipping similar frames: _ExpressionOptimizer._optimize_value at line 512 (1 times)]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:527, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     525 if self._is_always_liftable(referenced_value):
#     526   return referenced_value
# --> 527 return {'valueReference': self._optimize_referred_value(reference)}
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:444, in _ExpressionOptimizer._optimize_referred_value(self, reference_or_value)
#     442   mapped_reference = str(len(self._reference_map))
#     443   self._reference_map[reference_or_value] = mapped_reference
# --> 444   self._optimized_values[mapped_reference] = self._optimize_value(
#     445       self._values[reference_or_value], 0)
#     446   return mapped_reference
#     447 else:
#
#     [... skipping similar frames: _ExpressionOptimizer._optimize_value at line 512 (17 times), _ExpressionOptimizer._optimize_value at line 523 (16 times)]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:527, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     525 if self._is_always_liftable(referenced_value):
#     526   return referenced_value
# --> 527 return {'valueReference': self._optimize_referred_value(reference)}
#
#     [... skipping similar frames: _ExpressionOptimizer._optimize_value at line 512 (282 times), _ExpressionOptimizer._optimize_value at line 523 (265 times), _ExpressionOptimizer._optimize_referred_value at line 444 (17 times), _ExpressionOptimizer._optimize_value at line 527 (16 times)]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:527, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     525 if self._is_always_liftable(referenced_value):
#     526   return referenced_value
# --> 527 return {'valueReference': self._optimize_referred_value(reference)}
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:444, in _ExpressionOptimizer._optimize_referred_value(self, reference_or_value)
#     442   mapped_reference = str(len(self._reference_map))
#     443   self._reference_map[reference_or_value] = mapped_reference
# --> 444   self._optimized_values[mapped_reference] = self._optimize_value(
#     445       self._values[reference_or_value], 0)
#     446   return mapped_reference
#     447 else:
#
#     [... skipping similar frames: _ExpressionOptimizer._optimize_value at line 512 (15 times), _ExpressionOptimizer._optimize_value at line 523 (15 times)]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:523, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     521 referenced_value = self._values[reference]
#     522 if reference in self._single_uses and depth < _DEPTH_LIMIT:
# --> 523   return self._optimize_value(referenced_value, depth)
#     524 else:
#     525   if self._is_always_liftable(referenced_value):
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:470, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     465   return value
#     466 elif 'arrayValue' in value:
#     467   # Optimise recursively, then turn an array of constants into a constant
#     468   # array.
#     469   optimized_array = [
# --> 470       self._optimize_value(array_value, depth + 3)
#     471       for array_value in value['arrayValue']['values']
#     472   ]
#     473   if all(self._is_constant_value(v) for v in optimized_array):
#     474     optimized_array = [v['constantValue'] for v in optimized_array]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:527, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     525 if self._is_always_liftable(referenced_value):
#     526   return referenced_value
# --> 527 return {'valueReference': self._optimize_referred_value(reference)}
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:444, in _ExpressionOptimizer._optimize_referred_value(self, reference_or_value)
#     442   mapped_reference = str(len(self._reference_map))
#     443   self._reference_map[reference_or_value] = mapped_reference
# --> 444   self._optimized_values[mapped_reference] = self._optimize_value(
#     445       self._values[reference_or_value], 0)
#     446   return mapped_reference
#     447 else:
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:523, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     521 referenced_value = self._values[reference]
#     522 if reference in self._single_uses and depth < _DEPTH_LIMIT:
# --> 523   return self._optimize_value(referenced_value, depth)
#     524 else:
#     525   if self._is_always_liftable(referenced_value):
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:523, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     521 referenced_value = self._values[reference]
#     522 if reference in self._single_uses and depth < _DEPTH_LIMIT:
# --> 523   return self._optimize_value(referenced_value, depth)
#     524 else:
#     525   if self._is_always_liftable(referenced_value):
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:512, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     507   else:
#     508     optimized_invocation[
#     509         'functionReference'] = self._optimize_referred_value(
#     510             function_invocation['functionReference'])
#     511   optimized_invocation['arguments'] = {
# --> 512       k: self._optimize_value(v, depth + 3) for k, v in arguments.items()
#     513   }
#     514   return {'functionInvocationValue': optimized_invocation}
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:518, in _ExpressionOptimizer._optimize_value(self, value, depth)
#     515 elif 'valueReference' in value:
#     516   # Lift if possible: anything used only here, anything lightweight.
#     517   reference = value['valueReference']
# --> 518   if not self._is_compound():
#     519     return self._optimize_value(reference, depth)
#     521   referenced_value = self._values[reference]
#
# File c:\Users\mm1397\OneDrive - University of Exeter\Documents\PlotToSat\.venv\Lib\site-packages\ee\serializer.py:380, in _ExpressionOptimizer._is_compound(self)
#     377     self._optimized_values = {}
#     378     self._reference_map = {}
# --> 380 def _is_compound(self) -> bool:
#     381   return self._values is not None
#     383 def _find_single_uses(self) -> Set[Any]:
#
# KeyboardInterrupt:
