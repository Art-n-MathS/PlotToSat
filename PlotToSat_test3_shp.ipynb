# %%
# import all the necessary libraries
# import ee
# ee.Authenticate(force=True)
# ee.Initialize()


# %run PlotToSat.ipynb

# Define study region
countries = ee.FeatureCollection('USDOS/LSIB_SIMPLE/2017')
polygon = countries.filter(ee.Filter.eq('country_na', 'Spain'))

shp = {
   "shpfilename"        : "projects/ee-flf-milto/assets/samplePlots",
   "polygonKeyColumn"   : "PLOTCODE" # column that ids of polygons are stored
}
# Specify the year of interest
year = 2023



# Create an instance of the Manager
#myPlotToSat = PlotToSat(polygon,fieldData,year) 
myPlotToSat = PlotToSat(polygon,shp,year) 
myPlotToSat.setSampling(300)


# Add Earth Observation Collections of interest
myPlotToSat.addCollection("sentinel-1", False) 
#myPlotToSat.addCollection("sentinel-2", 50  ) 

myPlotToSat.exportStd(False)
myPlotToSat.exportMean(True) 


#Definition and exportation of outputs
# if run multiple times, use different feature vector names to avoid 
# creating tasks with the same ID in the GEE task manager and
# thus returning an expection
myPlotToSat.exportFeatures("Spain_shp", "feature_vectors_2022_shp")	


#myPlotToSat.exprtFeaturesMinMax("Greenbelts_2021_test", "feature_vectors_",170,175)
# Out:
# GEE already imported
# GEE already imported
# Class fieldData imported
# Masks class imported
# GEE already imported
# Return didn't work
# Sentinel1:  2024-01-01 2024-12-31
# Sentinel2:  2024-01-01 2024-12-31
# Shapefile  projects/ee-flf-milto/assets/finland_plots_buffered  is loaded with  2397  polygons
# Sampling size updated to 300
# NEW SAMPLING: =  300
# Sentinel 1 added
# Self.sampling size  300
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
# exporting collections
# Sentinel 1 collection parameters loaded are valid and system is now intepreting data
# Band names:  ['0_VHAsc', '1_VHAsc', '2_VHAsc', '3_VHAsc', '4_VHAsc', '5_VHAsc', '6_VHAsc', '7_VHAsc', '8_VHAsc', '9_VHAsc', '10_VHAsc', '11_VHAsc', '0_VVAsc', '1_VVAsc', '2_VVAsc', '3_VVAsc', '4_VVAsc', '5_VVAsc', '6_VVAsc', '7_VVAsc', '8_VVAsc', '9_VVAsc', '10_VVAsc', '11_VVAsc', '0_VHDes', '1_VHDes', '2_VHDes', '3_VHDes', '4_VHDes', '5_VHDes', '6_VHDes', '7_VHDes', '8_VHDes', '9_VHDes', '10_VHDes', '11_VHDes', '0_VVDes', '1_VVDes', '2_VVDes', '3_VVDes', '4_VVDes', '5_VVDes', '6_VVDes', '7_VVDes', '8_VVDes', '9_VVDes', '10_VVDes', '11_VVDes']
# START EXPORTING FEATURES VECTORS OF A SINGLE FILE
# WARNING: Sentinel 2 collection parameters loaded are NOT valid and system is skipping this collection
#     *** End of exportation = Check progress on the Tasks tab at GEE ***
